# %% [markdown]
# ### new partition

# %%
from utilities import *

all_files = glob.glob(os.path.join(TRAIN_AUDIO_DIR, '*/*wav'))

with open(os.path.join(TRAIN_DIR, 'validation_list.txt'), 'r') as fin:
    validation_files = fin.readlines()
valset = set()
for fname in validation_files:
    splits = fname.split('/')
    valset.add(splits[-1].split('_')[0].rstrip())
train, val = [], []
noise = [(NAME2ID['silence'], '', '')]
for fname in all_files:
    splits = fname.split('\\')
    label, uid = splits[-2], splits[-1].split('_')[0]
    if label == '_background_noise_':
        label = 'silence'

    sample = (label, uid, fname)
    if uid in valset:
        val.append(sample)
    elif label == 'silence':
        noise.append(sample)
    else:
        train.append(sample)

print('There are {} train and {} val samples'.format(len(train), len(val)))
# Out:
# There are 57923 train and 6798 val samples

# %%
from collections import Counter
count_train = Counter([s[0] for s in train])
for k in count_train.keys():
    print('{}:\t{},\t{}'.format(k, count_train[k], count_train[k] / len(train)))
# Out:
# four:	2092,	0.036116913833882915
# stop:	2134,	0.03684201439842549
# yes:	2116,	0.03653125701362153
# dog:	1576,	0.027208535469502616
# right:	2111,	0.036444935517842655
# left:	2106,	0.03635861402206377
# bed:	1516,	0.02617267752015607
# five:	2115,	0.03651399271446576
# three:	2108,	0.036393142620375324
# bird:	1569,	0.027087685375412184
# wow:	1579,	0.027260328366969944
# on:	2110,	0.036427671218686876
# happy:	1553,	0.02681145658891977
# no:	2105,	0.036341349722908
# six:	2107,	0.03637587832121955
# nine:	2134,	0.03684201439842549
# up:	2115,	0.03651399271446576
# two:	2137,	0.036893807295892825
# seven:	2114,	0.03649672841530998
# go:	2112,	0.03646219981699843
# cat:	1565,	0.027018628178789084
# one:	2140,	0.03694560019336015
# house:	1577,	0.027225799768658392
# down:	2095,	0.03616870673135024
# zero:	2116,	0.03653125701362153
# tree:	1567,	0.027053156777100632
# marvin:	1586,	0.027381178461060373
# off:	2101,	0.036272292526284895
# sheila:	1558,	0.02689777808469865
# eight:	2109,	0.0364104069195311

# %%
count_val = Counter([s[0] for s in val])
for k in count_val.keys():
    print('{}:\t{},\t{}'.format(k, count_val[k], count_val[k] / len(val)))
# Out:
# four:	280,	0.04118858487790527
# stop:	246,	0.03618711385701677
# yes:	261,	0.038393645189761696
# dog:	170,	0.025007355104442484
# right:	256,	0.03765813474551338
# left:	247,	0.03633421594586643
# bed:	197,	0.028979111503383347
# five:	242,	0.03559870550161812
# three:	248,	0.03648131803471609
# bird:	162,	0.02383053839364519
# wow:	166,	0.024418946749043838
# on:	257,	0.03780523683436305
# happy:	189,	0.027802294792586054
# no:	270,	0.03971756398940865
# six:	262,	0.038540747278611356
# nine:	230,	0.033833480435422184
# up:	260,	0.03824654310091203
# two:	236,	0.03471609296852015
# seven:	263,	0.038687849367461016
# go:	260,	0.03824654310091203
# cat:	168,	0.02471315092674316
# one:	230,	0.033833480435422184
# house:	173,	0.025448661370991468
# down:	264,	0.038834951456310676
# zero:	260,	0.03824654310091203
# tree:	166,	0.024418946749043838
# marvin:	160,	0.023536334215945868
# off:	256,	0.03765813474551338
# sheila:	176,	0.025889967637540454
# eight:	243,	0.03574580759046778

# %%
all_files = glob.glob(os.path.join(TRAIN_MODIFIED_AUDIO_DIR, '*/*wav'))
uids = []
f_sil = []
for fname in all_files:
    splits = fname.split('\\')
    label, uid = splits[-2], splits[-1].split('_')[0]
    if label == '_background_noise_':
        f_sil.append(fname)
    else:
        uids.append(uid)
uids = np.unique(uids)
f_sil = np.unique(f_sil)

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=17)
uids_folds = []
for train_index, test_index in kf.split(uids):
    uids_folds.append([uids[train_index], uids[test_index]])

sil_folds = []
for train_index, test_index in kf.split(f_sil):
    sil_folds.append([f_sil[train_index], f_sil[test_index]])

# %%
for uid_f in uids_folds:
    print (len(uid_f[0]), len(uid_f[1]))
    for i in uid_f[0]:
        assert i not in uid_f[1]
        
for f in sil_folds:
    print (len(f[0]), len(f[1]))
    for i in f[0]:
        assert i not in f[1]
# Out:
# 1409 470
# 1409 470
# 1409 470
# 1410 469
# 6264 2089
# 6265 2088
# 6265 2088
# 6265 2088

# %%
all_files = glob.glob(os.path.join(TRAIN_MODIFIED_AUDIO_DIR, '*/*wav'))
folds = []
for i in range(len(uids_folds)):
    uid_f = uids_folds[i]
    sil_f = sil_folds[i]
    
    train_f = []
    test_f = []
    for fname in all_files:
        splits = fname.split('\\')
        label, uid = splits[-2], splits[-1].split('_')[0]
        if uid in uid_f[0] or fname in sil_f[0]:
            train_f.append(fname)
        elif uid in uid_f[1] or fname in sil_f[1]:
            test_f.append(fname)
        else:
            print(uid)
            print('WTF?!')
    folds.append([train_f, test_f])

# %%
for f in folds:
    print (len(f[0]), len(f[1]))
    for i in f[0]:
        assert i not in f[1]
# Out:
# 54171 18056
# 54556 17671
# 53922 18305
# 54599 17628

# %%
from collections import Counter

def test_folds(folds):
    for fold in folds:
        train_files = [f.split('\\')[-2] + f.split('\\')[-1] for f in fold[0]]
        val_files = [f.split('\\')[-2] + f.split('\\')[-1] for f in fold[1]]

        all_files = glob.glob(os.path.join(TRAIN_MODIFIED_AUDIO_DIR, '*/*wav'))

        train, val = [], []
        for fname in all_files:
            splits = fname.split('\\')
            label, uid = splits[-2], splits[-1].split('_')[0]
            if label == '_background_noise_':
                label = 'silence'
            sample = (label, uid, fname)
            sample_id = splits[-2] + splits[-1]
            if sample_id in val_files:
                val.append(sample)
            elif sample_id in train_files:
                train.append(sample)
        print('There are {} train and {} val samples'.format(len(train), len(val)))

        count_train = Counter([s[0] for s in train])
        count_val = Counter([s[0] for s in val])
        for k in count_train.keys():
            print('{}:\t{}\t-\t{},\t{}\t-\t{}'.format(k, count_train[k], count_val[k], count_train[k] / len(train), count_val[k] / len(val)))
        print('==============================================================')

# %%
test_folds(folds)
# Out:
# There are 54171 train and 18056 val samples
# four:	1769	-	573,	0.0326558490705359	-	0.03173460345591493
# stop:	1748	-	599,	0.03226818777574717	-	0.033174568010633586
# yes:	1776	-	574,	0.032785069502132135	-	0.031789986708019496
# dog:	1288	-	453,	0.02377655941370844	-	0.0250886132033673
# right:	1729	-	591,	0.031917446604271656	-	0.032731501993797076
# left:	1733	-	582,	0.03199128685089808	-	0.03223305272485601
# bed:	1280	-	431,	0.023628878920455593	-	0.0238701816570669
# five:	1727	-	601,	0.031880526480958446	-	0.03328533451484271
# three:	1707	-	558,	0.03151132524782633	-	0.030903854674346476
# bird:	1276	-	446,	0.02355503867382917	-	0.024700930438635357
# wow:	1269	-	465,	0.02342581824223293	-	0.025753212228622063
# on:	1769	-	555,	0.0326558490705359	-	0.030737704918032786
# happy:	1275	-	454,	0.023536578612172565	-	0.025143996455471867
# no:	1780	-	567,	0.03285890974875856	-	0.03140230394328755
# silence:	6367	-	1986,	0.11753521256760997	-	0.10999113867966327
# six:	1760	-	564,	0.03248970851562644	-	0.03123615418697386
# nine:	1756	-	568,	0.03241586826900002	-	0.03145768719539211
# up:	1733	-	590,	0.03199128685089808	-	0.03267611874169251
# two:	1762	-	577,	0.03252662863893965	-	0.031956136464333186
# seven:	1750	-	586,	0.03230510789906038	-	0.032454585733274255
# go:	1759	-	574,	0.032471248453969835	-	0.031789986708019496
# cat:	1262	-	464,	0.02329659781063669	-	0.0256978289765175
# one:	1729	-	606,	0.031917446604271656	-	0.03356225077536553
# house:	1308	-	437,	0.02414576064684056	-	0.024202481169694284
# down:	1738	-	591,	0.03208358715918111	-	0.032731501993797076
# zero:	1756	-	583,	0.03241586826900002	-	0.032288435976960565
# tree:	1344	-	419,	0.024810322866478374	-	0.02320558263181214
# marvin:	1268	-	458,	0.023407358180576324	-	0.02536552946389012
# off:	1763	-	558,	0.03254508870059626	-	0.030903854674346476
# sheila:	1283	-	437,	0.02368425910542541	-	0.024202481169694284
# eight:	1707	-	609,	0.03151132524782633	-	0.03372840053167922
# ==============================================================
# There are 54556 train and 17671 val samples
# four:	1763	-	579,	0.03231541901898966	-	0.032765548073114145
# stop:	1761	-	586,	0.03227875943984163	-	0.03316167732442986
# yes:	1783	-	567,	0.03268201481046998	-	0.032086469356572916
# dog:	1313	-	428,	0.0240670137106826	-	0.024220474223303718
# right:	1782	-	538,	0.03266368502089596	-	0.030445362458264954
# left:	1754	-	561,	0.03215045091282352	-	0.0317469299983023
# bed:	1269	-	442,	0.02326050296942591	-	0.025012732725935148
# five:	1766	-	562,	0.032370408387711706	-	0.03180351989134741
# three:	1717	-	548,	0.03147224869858494	-	0.031011261388715974
# bird:	1291	-	431,	0.023663758340054256	-	0.024390243902439025
# wow:	1318	-	416,	0.02415866265855268	-	0.023541395506762493
# on:	1729	-	595,	0.031692206173473125	-	0.03367098636183578
# happy:	1302	-	427,	0.02386538602536843	-	0.024163884330258616
# no:	1769	-	578,	0.03242539775643376	-	0.03270895818006904
# silence:	6431	-	1922,	0.11787887675049491	-	0.10876577443268633
# six:	1721	-	603,	0.031545567856881	-	0.034123705506196596
# nine:	1745	-	579,	0.03198548280665738	-	0.032765548073114145
# up:	1785	-	538,	0.03271867438961801	-	0.030445362458264954
# two:	1769	-	570,	0.03242539775643376	-	0.03225623903570822
# seven:	1754	-	582,	0.03215045091282352	-	0.03293531775224945
# go:	1736	-	597,	0.031820514700491236	-	0.03378416614792598
# cat:	1311	-	415,	0.024030354131534568	-	0.02348480561371739
# one:	1767	-	568,	0.03238873817728573	-	0.032143059249618015
# house:	1326	-	419,	0.024305300975144804	-	0.0237111651858978
# down:	1758	-	571,	0.03222377007111958	-	0.032312828928753326
# zero:	1763	-	576,	0.03231541901898966	-	0.032595778393978835
# tree:	1288	-	475,	0.023608768971332208	-	0.02688019919642352
# marvin:	1282	-	444,	0.023498790233888116	-	0.025125912512025353
# off:	1743	-	578,	0.031948823227509346	-	0.03270895818006904
# sheila:	1283	-	437,	0.02351712002346213	-	0.024729783260709636
# eight:	1777	-	539,	0.03257203607302588	-	0.030501952351310056
# ==============================================================
# There are 53922 train and 18305 val samples
# four:	1733	-	609,	0.03213901561514781	-	0.03326959847036329
# stop:	1736	-	611,	0.03219465153369682	-	0.03337885823545479
# yes:	1731	-	619,	0.0321019250027818	-	0.03381589729582082
# dog:	1306	-	435,	0.024220169875004638	-	0.02376399890740235
# right:	1702	-	618,	0.031564111123474646	-	0.033761267413275065
# left:	1699	-	616,	0.03150847520492563	-	0.03365200764818355
# bed:	1307	-	404,	0.024238715181187642	-	0.02207047254848402
# five:	1722	-	606,	0.03193501724713475	-	0.03310570882272603
# three:	1673	-	592,	0.0310262972441675	-	0.03234089046708549
# bird:	1295	-	427,	0.02401617150699158	-	0.023326959847036328
# wow:	1287	-	447,	0.02386780905752754	-	0.02441955749795138
# on:	1734	-	590,	0.03215756092133081	-	0.03223163070199399
# happy:	1319	-	410,	0.0244612588553837	-	0.022398251843758536
# no:	1720	-	627,	0.03189792663476874	-	0.034252936356186835
# silence:	6397	-	1956,	0.1186343236526835	-	0.10685605025949194
# six:	1736	-	588,	0.03219465153369682	-	0.03212237093690248
# nine:	1723	-	601,	0.03195356255331776	-	0.03283255940999727
# up:	1738	-	585,	0.03223174214606283	-	0.03195848128926523
# two:	1734	-	605,	0.03215756092133081	-	0.03305107894018028
# seven:	1746	-	590,	0.03238010459552687	-	0.03223163070199399
# go:	1717	-	616,	0.031842290716219725	-	0.03365200764818355
# cat:	1284	-	442,	0.023812173138978526	-	0.02414640808522262
# one:	1743	-	592,	0.03232446867697786	-	0.03234089046708549
# house:	1311	-	434,	0.024312896405919663	-	0.023709369024856597
# down:	1721	-	608,	0.03191647194095174	-	0.033214968587817535
# zero:	1724	-	615,	0.03197210785950076	-	0.0335973777656378
# tree:	1351	-	412,	0.025054708653239863	-	0.02250751160885004
# marvin:	1331	-	395,	0.024683802529579763	-	0.02157880360557225
# off:	1687	-	634,	0.031285931530729574	-	0.0346353455340071
# sheila:	1292	-	428,	0.023960535588442564	-	0.02338158972958208
# eight:	1723	-	593,	0.03195356255331776	-	0.03239552034963125
# ==============================================================
# There are 54599 train and 17628 val samples
# four:	1761	-	581,	0.032253337973222954	-	0.03295892897662809
# stop:	1796	-	551,	0.03289437535485998	-	0.031257090991604265
# yes:	1760	-	590,	0.032235022619461894	-	0.03346948037213524
# dog:	1316	-	425,	0.02410300554955219	-	0.0241093714545042
# right:	1747	-	573,	0.03199692302056814	-	0.03250510551395507
# left:	1759	-	556,	0.03221670726570084	-	0.0315407306557749
# bed:	1277	-	434,	0.02338870675287093	-	0.024619922850011345
# five:	1769	-	559,	0.03239986080331141	-	0.03171091445427729
# three:	1698	-	567,	0.031099470686276304	-	0.032164737916950306
# bird:	1304	-	418,	0.023883221304419496	-	0.023712275924665304
# wow:	1328	-	406,	0.024322789794684885	-	0.023031540730655775
# on:	1740	-	584,	0.031868715544240735	-	0.033129112775130476
# happy:	1291	-	438,	0.023645121705525744	-	0.024846834581347857
# no:	1772	-	575,	0.03245480686459459	-	0.03261856137962332
# silence:	6431	-	1922,	0.11778604003736332	-	0.1090310869071931
# six:	1755	-	569,	0.03214344585065661	-	0.032278193782618564
# nine:	1748	-	576,	0.0320152383743292	-	0.03267528931245745
# up:	1713	-	610,	0.031374200992692176	-	0.03460403902881779
# two:	1752	-	587,	0.032088499789373434	-	0.033299296573632856
# seven:	1758	-	578,	0.03219839191193978	-	0.03278874517812571
# go:	1787	-	546,	0.03272953717101046	-	0.030973451327433628
# cat:	1321	-	405,	0.02419458231835748	-	0.022974812797821646
# one:	1766	-	569,	0.03234491474202824	-	0.032278193782618564
# house:	1290	-	455,	0.023626806351764684	-	0.025811209439528023
# down:	1770	-	559,	0.03241817615707247	-	0.03171091445427729
# zero:	1774	-	565,	0.032491437572116706	-	0.03205128205128205
# tree:	1306	-	457,	0.02391985201194161	-	0.025924665305196277
# marvin:	1297	-	429,	0.02375501382809209	-	0.024336283185840708
# off:	1770	-	551,	0.03241817615707247	-	0.031257090991604265
# sheila:	1302	-	418,	0.02384659059689738	-	0.023712275924665304
# eight:	1741	-	575,	0.031887030898001795	-	0.03261856137962332
# ==============================================================

# %%
with gzip.open(TRAIN_MODIFIED_DIR + 'kfold4_max.pklz', 'wb') as f:
    pickle.dump(folds, f)

# %%
my_folds = pickle.load(gzip.open(TRAIN_MODIFIED_DIR + 'kfold4_max.pklz', 'rb'))
assert (my_folds == folds)

# %%
import pickle
import gzip

our_folds = pickle.load(gzip.open(TRAIN_MODIFIED_DIR + KFOLD_FILENAME, 'rb'))

# %%
test_folds(our_folds)
# Out:
# There are 53504 train and 18717 val samples
# four:	2342	-	0,	0.043772428229665074	-	0.0
# stop:	1768	-	579,	0.033044258373205744	-	0.030934444622535664
# dog:	1741	-	0,	0.03253962320574163	-	0.0
# right:	1742	-	578,	0.03255831339712919	-	0.030881017257039057
# left:	1723	-	592,	0.03220319976076555	-	0.03162900037399156
# bed:	1711	-	0,	0.03197891746411483	-	0.0
# five:	2328	-	0,	0.043510765550239236	-	0.0
# three:	2265	-	0,	0.04233328349282297	-	0.0
# bird:	1722	-	0,	0.03218450956937799	-	0.0
# yes:	1734	-	616,	0.032408791866028706	-	0.03291125714591014
# on:	1724	-	600,	0.03222188995215311	-	0.03205641929796442
# happy:	1729	-	0,	0.03231534090909091	-	0.0
# no:	1762	-	585,	0.03293211722488038	-	0.03125500881551531
# silence:	6040	-	2307,	0.11288875598086125	-	0.12325693220067319
# six:	2324	-	0,	0.043436004784688995	-	0.0
# seven:	2336	-	0,	0.04366028708133971	-	0.0
# up:	1734	-	589,	0.032408791866028706	-	0.03146871827750174
# two:	2339	-	0,	0.04371635765550239	-	0.0
# sheila:	1720	-	0,	0.03214712918660287	-	0.0
# go:	1733	-	600,	0.032390101674641146	-	0.03205641929796442
# cat:	1726	-	0,	0.03225927033492823	-	0.0
# house:	1745	-	0,	0.03261438397129186	-	0.0
# down:	1712	-	617,	0.03199760765550239	-	0.032964684511406744
# tree:	1763	-	0,	0.03295080741626794	-	0.0
# off:	1725	-	596,	0.03224058014354067	-	0.031842709835977985
# eight:	2316	-	0,	0.04328648325358852	-	0.0
# ==============================================================
# There are 53793 train and 18428 val samples
# four:	2342	-	0,	0.04353726321268567	-	0.0
# stop:	1727	-	620,	0.032104548919004335	-	0.03364445409159974
# yes:	1725	-	625,	0.03206736936032569	-	0.03391578033427393
# dog:	1741	-	0,	0.0323648058297548	-	0.0
# right:	1685	-	635,	0.03132377818675292	-	0.03445843281962231
# left:	1747	-	568,	0.03247634450579072	-	0.03082266116778815
# five:	2328	-	0,	0.0432770063019352	-	0.0
# bird:	1722	-	0,	0.03201160002230773	-	0.0
# wow:	1734	-	0,	0.032234677374379565	-	0.0
# on:	1736	-	588,	0.0322718569330582	-	0.031907966138484914
# happy:	1729	-	0,	0.03214172847768297	-	0.0
# no:	1726	-	621,	0.03208595913966501	-	0.033698719340134575
# silence:	6345	-	2002,	0.11795214990798059	-	0.10863902756674626
# six:	2324	-	0,	0.04320264718457792	-	0.0
# nine:	2324	-	0,	0.04320264718457792	-	0.0
# up:	1709	-	614,	0.031769932890896586	-	0.03331886260039071
# sheila:	1720	-	0,	0.0319744204636291	-	0.0
# go:	1737	-	596,	0.03229044671239752	-	0.03234208812676362
# cat:	1726	-	0,	0.03208595913966501	-	0.0
# one:	2335	-	0,	0.04340713475731043	-	0.0
# down:	1738	-	591,	0.032309036491736845	-	0.03207076188408943
# zero:	2339	-	0,	0.04348149387466771	-	0.0
# tree:	1763	-	0,	0.032773780975219824	-	0.0
# marvin:	1726	-	0,	0.03208595913966501	-	0.0
# off:	1749	-	572,	0.032513524064469355	-	0.0310397221619275
# eight:	2316	-	0,	0.04305392894986337	-	0.0
# ==============================================================
# There are 54180 train and 18041 val samples
# left:	1748	-	567,	0.032262827611664824	-	0.03142841305914306
# stop:	1775	-	572,	0.03276116648209672	-	0.03170555955878277
# yes:	1779	-	571,	0.03283499446290144	-	0.03165013025885483
# no:	1752	-	595,	0.032336655592469545	-	0.03298043345712544
# right:	1781	-	539,	0.0328719084533038	-	0.02987639266116069
# one:	2335	-	0,	0.04309708379475821	-	0.0
# house:	1745	-	0,	0.032207456626061275	-	0.0
# five:	2328	-	0,	0.04296788482834994	-	0.0
# three:	2265	-	0,	0.04180509413067553	-	0.0
# wow:	1734	-	0,	0.032004429678848284	-	0.0
# on:	1774	-	550,	0.03274270948689553	-	0.03048611496036805
# happy:	1729	-	0,	0.03191214470284238	-	0.0
# silence:	6374	-	1973,	0.11764488741232927	-	0.1093620087578294
# nine:	2324	-	0,	0.04289405684754522	-	0.0
# up:	1772	-	551,	0.03270579549649317	-	0.030541544260295993
# two:	2339	-	0,	0.04317091177556294	-	0.0
# seven:	2336	-	0,	0.0431155407899594	-	0.0
# go:	1775	-	558,	0.03276116648209672	-	0.030929549359791586
# cat:	1726	-	0,	0.031856773717238836	-	0.0
# bed:	1711	-	0,	0.03157991878922112	-	0.0
# down:	1784	-	545,	0.032927279438907345	-	0.03020896846072834
# zero:	2339	-	0,	0.04317091177556294	-	0.0
# tree:	1763	-	0,	0.03253968253968254	-	0.0
# marvin:	1726	-	0,	0.031856773717238836	-	0.0
# off:	1746	-	575,	0.03222591362126246	-	0.031871847458566596
# sheila:	1720	-	0,	0.031746031746031744	-	0.0
# ==============================================================
# There are 55186 train and 17035 val samples
# four:	2342	-	0,	0.0424382995687312	-	0.0
# stop:	1771	-	576,	0.03209147247490306	-	0.03381273847960082
# yes:	1812	-	538,	0.032834414525423114	-	0.031582036982682714
# dog:	1741	-	0,	0.031547856340376185	-	0.0
# right:	1752	-	568,	0.03174718225636937	-	0.03334311711182859
# left:	1727	-	588,	0.031294168810930306	-	0.034517170531259175
# bed:	1711	-	0,	0.03100424020584931	-	0.0
# three:	2265	-	0,	0.041043018156778896	-	0.0
# bird:	1722	-	0,	0.031203566121842496	-	0.0
# wow:	1734	-	0,	0.031421012575653245	-	0.0
# on:	1738	-	586,	0.0314934947269235	-	0.03439976518931612
# no:	1801	-	546,	0.03263508860942993	-	0.03205165835045495
# silence:	6282	-	2065,	0.11383321856992716	-	0.1212210155562078
# six:	2324	-	0,	0.042112129888015076	-	0.0
# nine:	2324	-	0,	0.042112129888015076	-	0.0
# up:	1754	-	569,	0.03178342333200449	-	0.033401819782800116
# two:	2339	-	0,	0.04238393795527851	-	0.0
# seven:	2336	-	0,	0.042329576341825825	-	0.0
# go:	1754	-	579,	0.03178342333200449	-	0.03398884649251541
# one:	2335	-	0,	0.04231145580400826	-	0.0
# house:	1745	-	0,	0.03162033849164643	-	0.0
# down:	1753	-	576,	0.031765302794186934	-	0.03381273847960082
# zero:	2339	-	0,	0.04238393795527851	-	0.0
# marvin:	1726	-	0,	0.03127604827311275	-	0.0
# off:	1743	-	578,	0.03158409741601131	-	0.03393014382154388
# eight:	2316	-	0,	0.04196716558547458	-	0.0
# ==============================================================

# %%
from utilities import *
import pickle
import gzip

folds = pickle.load(gzip.open(TRAIN_MODIFIED_DIR + MY_KFOLD_FILENAME, 'rb'))

for i in range(len(folds)):
    trainset, valset = load_fold(folds[i], no_unk=False)
    val_files = [v[2] for v in valset]
    train_files = [v[2] for v in trainset]
    for f in val_files:
        if f in train_files:
            print(f)
# Out:
# C:\Users\MAX\Anaconda2\envs\tf\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# There are 54171 train and 18056 val samples
# There are 54556 train and 17671 val samples
# There are 53922 train and 18305 val samples
# There are 54599 train and 17628 val samples

# %%
for i in range(len(folds)):
    trainset, valset = load_fold(folds[i], no_unk=True)
    val_files = [v[2] for v in valset]
    train_files = [v[2] for v in trainset]
    for f in val_files:
        if f in train_files:
            print(f)
# Out:
# There are 54171 train and 7767 val samples
# There are 54556 train and 7631 val samples
# There are 53922 train and 8080 val samples
# There are 54599 train and 7617 val samples

# %%
for i in range(len(folds)):
    trainset, valset = load_fold(folds[i], no_unk=False)
    val_uids = np.unique([v[1] for v in valset])
    train_uids = np.unique([v[1] for v in trainset])
    for i in val_uids:
        if i in train_uids:
            print(i)

# %%
for i in range(len(folds)):
    trainset, valset = load_fold(folds[i], no_unk=True)
    val_uids = np.unique([v[1] for v in valset])
    train_uids = np.unique([v[1] for v in trainset])
    for i in val_uids:
        if i in train_uids:
            print(i)
# Out:
# There are 54171 train and 7767 val samples
# 05b2db80
# 122c5aa7
# 190821dc
# 2bdbe5f7
# 3bfd30e6
# 3d53244b
# 533c6564
# 611d2b50
# 6727b579
# 6c968bd9
# 763188c4
# 88120683
# 94de6a6a
# 953fe1ad
# 96ab6565
# 9aa21fa9
# alexbluenoise
# alexbrownnoise
# alexdoingthedishes
# alexdudemiaowing
# alexexercisebike
# alexpinknoise
# alexrunningtap
# alexvioletnoise
# alexwhitenoise
# b0bad4a9
# b9515bf3
# b959cd0c
# b9f46737
# bab36420
# c93d5e22
# cd85758f
# ce7a8e92
# d90b4138
# dbb40d24
# dea820ce
# e7ea8b76
# e96a5020
# eb3f7d82
# ee4a907f
# f953e1af
# fd395b74
# twlgdeye
# zfturbo
# There are 54556 train and 7631 val samples
# 0132a06d
# 099d52ad
# 2da58b32
# 35d1b6ee
# 38d78313
# 3f2b358d
# 40115b19
# 43691f67
# 53eb0a88
# 712e4d58
# 7211390b
# 7846fd85
# 7f74626f
# 7fd25f7c
# 888a0c49
# 9ff2d2f4
# a6d586b7
# alexbluenoise
# alexbrownnoise
# alexdoingthedishes
# alexdudemiaowing
# alexexercisebike
# alexpinknoise
# alexrunningtap
# alexvioletnoise
# alexwhitenoise
# b4aa9fef
# d9462202
# e0315cf6
# e96a5020
# ec201020
# twlgdeye
# zfturbo
# There are 53922 train and 8080 val samples
# 0137b3f4
# 179a61b7
# 1bc45db9
# 1cb788bc
# 1eddce1d
# 28ce0c58
# 28ed6bc9
# 29fb33da
# 2b3f509b
# 36050ef3
# 3bc21161
# 3ea77ede
# 439c84f4
# 49af4432
# 51055bda
# 563aa4e6
# 5b09db89
# 6c429c7b
# 70a00e98
# 735845ab
# 77def3ee
# 7e783e3f
# 7ea032f3
# 8830e17f
# 8eb4a1bf
# 964e8cfd
# 96a48d28
# 9886d8bf
# 9a7c1f83
# alexbluenoise
# alexbrownnoise
# alexdoingthedishes
# alexdudemiaowing
# alexexercisebike
# alexpinknoise
# alexrunningtap
# alexvioletnoise
# alexwhitenoise
# b4604db4
# bdee441c
# be7a5b2d
# c120e80e
# c137814b
# ced835d3
# d197e3ae
# e5dadd24
# e62056e2
# e96a5020
# f17be97f
# f8f60f59
# twlgdeye
# zfturbo
# There are 54599 train and 7617 val samples
# 1fd85ee4
# 24ad3ebe
# 264f471d
# 37dca74f
# 39a12648
# 46a153d8
# 4a1e736b
# 686d030b
# 692a88e6
# 742d6431
# 7c1d8533
# 834f03fe
# 8f4c551f
# 92a9c5e6
# 9f22307d
# ad63d93c
# aff582a1
# alexbluenoise
# alexbrownnoise
# alexdoingthedishes
# alexdudemiaowing
# alexexercisebike
# alexpinknoise
# alexrunningtap
# alexvioletnoise
# alexwhitenoise
# b1114e4f
# b87bdb22
# b97c9f77
# c0445658
# df038de4
# e1469561
# e41a903b
# e53139ad
# e96a5020
# f5733968
# twlgdeye
# zfturbo

# %%
trainset, valset = load_fold(folds[0], no_unk=True)
for s in trainset:
    if s[1] == '122c5aa7':
        print(s)
print('---------------------------------')
for s in valset:
    if s[1] == '122c5aa7':
        print(s)
# Out:
# There are 54171 train and 7767 val samples
# (10, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\_background_noise_\\122c5aa7_nohash_1.wav')
# (10, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\_background_noise_\\122c5aa7_nohash_3.wav')
# (10, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\_background_noise_\\122c5aa7_nohash_4641.wav')
# ---------------------------------
# (3, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\down\\122c5aa7_nohash_0.wav')
# (3, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\down\\122c5aa7_nohash_1.wav')
# (3, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\down\\122c5aa7_nohash_2.wav')
# (3, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\down\\122c5aa7_nohash_3.wav')
# (3, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\down\\122c5aa7_nohash_4.wav')
# (9, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\go\\122c5aa7_nohash_0.wav')
# (9, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\go\\122c5aa7_nohash_1.wav')
# (9, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\go\\122c5aa7_nohash_2.wav')
# (9, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\go\\122c5aa7_nohash_3.wav')
# (9, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\go\\122c5aa7_nohash_4.wav')
# (4, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\left\\122c5aa7_nohash_0.wav')
# (4, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\left\\122c5aa7_nohash_1.wav')
# (4, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\left\\122c5aa7_nohash_2.wav')
# (4, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\left\\122c5aa7_nohash_3.wav')
# (4, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\left\\122c5aa7_nohash_4.wav')
# (1, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\no\\122c5aa7_nohash_0.wav')
# (1, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\no\\122c5aa7_nohash_1.wav')
# (1, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\no\\122c5aa7_nohash_2.wav')
# (1, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\no\\122c5aa7_nohash_3.wav')
# (1, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\no\\122c5aa7_nohash_4.wav')
# (7, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\off\\122c5aa7_nohash_0.wav')
# (7, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\off\\122c5aa7_nohash_1.wav')
# (7, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\off\\122c5aa7_nohash_2.wav')
# (7, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\off\\122c5aa7_nohash_3.wav')
# (7, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\off\\122c5aa7_nohash_4.wav')
# (6, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\on\\122c5aa7_nohash_0.wav')
# (6, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\on\\122c5aa7_nohash_1.wav')
# (6, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\on\\122c5aa7_nohash_2.wav')
# (6, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\on\\122c5aa7_nohash_3.wav')
# (6, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\on\\122c5aa7_nohash_4.wav')
# (5, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\right\\122c5aa7_nohash_0.wav')
# (5, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\right\\122c5aa7_nohash_1.wav')
# (5, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\right\\122c5aa7_nohash_2.wav')
# (5, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\right\\122c5aa7_nohash_3.wav')
# (8, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\stop\\122c5aa7_nohash_0.wav')
# (8, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\stop\\122c5aa7_nohash_1.wav')
# (8, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\stop\\122c5aa7_nohash_2.wav')
# (8, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\stop\\122c5aa7_nohash_3.wav')
# (8, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\stop\\122c5aa7_nohash_4.wav')
# (2, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\up\\122c5aa7_nohash_0.wav')
# (2, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\up\\122c5aa7_nohash_1.wav')
# (2, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\up\\122c5aa7_nohash_2.wav')
# (2, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\up\\122c5aa7_nohash_3.wav')
# (0, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\yes\\122c5aa7_nohash_0.wav')
# (0, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\yes\\122c5aa7_nohash_1.wav')
# (0, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\yes\\122c5aa7_nohash_2.wav')
# (0, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\yes\\122c5aa7_nohash_3.wav')
# (0, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\yes\\122c5aa7_nohash_4.wav')
# (10, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\_background_noise_\\122c5aa7_nohash_1176.wav')
# (10, '122c5aa7', 'C:/data/tf_speech/train_modified/audio\\_background_noise_\\122c5aa7_nohash_4.wav')

# %%
train_uids
# Out:
# array(['00176480', '00b01445', '00f0204f', ..., 'twlgdeye', 'white',
#        'zfturbo'], dtype='<U18')

# %% [markdown]
# ## KFold: my noise, by speakers

# %%
all_files = glob.glob(os.path.join(TRAIN_AUDIO_DIR, '*/*wav'))
uids = []
f_sil = []
for fname in all_files:
    splits = fname.split('\\')
    label, uid = splits[-2], splits[-1].split('_')[0]
    if label == '_background_noise_':
        f_sil.append(fname)
        continue
    else:
        uids.append(uid)
uids = np.unique(uids)
f_sil = np.unique(f_sil)

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=17)
uids_folds = []
for train_index, test_index in kf.split(uids):
    uids_folds.append([uids[train_index], uids[test_index]])

# %%
for uid_f in uids_folds:
    print (len(uid_f[0]), len(uid_f[1]))
    for i in uid_f[0]:
        assert i not in uid_f[1]
# Out:
# 1410 471
# 1411 470
# 1411 470
# 1411 470

# %%
all_files = glob.glob(os.path.join(TRAIN_AUDIO_DIR, '*/*wav'))
folds = []
for i in range(len(uids_folds)):
    uid_f = uids_folds[i]
    
    train_f = []
    test_f = []
    for fname in all_files:
        splits = fname.split('\\')
        label, uid = splits[-2], splits[-1].split('_')[0]
        if label == '_background_noise_':
            continue
        if uid in uid_f[0]:
            train_f.append(fname)
        elif uid in uid_f[1]:
            test_f.append(fname)
        else:
            print(uid)
            print('WTF?!')
    folds.append([train_f, test_f])

# %%
for f in folds:
    print (len(f[0]), len(f[1]))
    for i in f[0]:
        assert i not in f[1]
# Out:
# 54171 18056
# 54556 17671
# 53922 18305
# 54599 17628

# %%
from collections import Counter

def test_folds(folds):
    for fold in folds:
        train_files = [f.split('\\')[-2] + f.split('\\')[-1] for f in fold[0]]
        val_files = [f.split('\\')[-2] + f.split('\\')[-1] for f in fold[1]]

        all_files = glob.glob(os.path.join(TRAIN_AUDIO_DIR, '*/*wav'))

        train, val = [], []
        for fname in all_files:
            splits = fname.split('\\')
            label, uid = splits[-2], splits[-1].split('_')[0]
            if label == '_background_noise_':
                print(fname)
                continue
            sample = (label, uid, fname)
            sample_id = splits[-2] + splits[-1]
            if sample_id in val_files:
                val.append(sample)
            elif sample_id in train_files:
                train.append(sample)
        print('There are {} train and {} val samples'.format(len(train), len(val)))

        count_train = Counter([s[0] for s in train])
        count_val = Counter([s[0] for s in val])
        for k in count_train.keys():
            print('{}:\t{}\t-\t{},\t{}\t-\t{}'.format(k, count_train[k], count_val[k], count_train[k] / len(train), count_val[k] / len(val)))
        print('==============================================================')

# %%
folds = pickle.load(gzip.open(TRAIN_MODIFIED_DIR + MY_KFOLD_FILENAME, 'rb'))

for f in folds:
    print(len(f[0]), len(f[1]))
    
    count = 0
    for fname in f[0]:
        splits = fname.split('\\')
        label, uid = splits[-2], splits[-1].split('_')[0]
        if label == '_background_noise_':
            continue
        count += 1
    print(count)
    
    count = 0
    for fname in f[1]:
        splits = fname.split('\\')
        label, uid = splits[-2], splits[-1].split('_')[0]
        if label == '_background_noise_':
            continue
        count += 1
    print(count)
# Out:
# 54171 18056
# 47804
# 16070
# 54556 17671
# 48125
# 15749
# 53922 18305
# 47525
# 16349
# 54599 17628
# 48168
# 15706

# %%
folds = pickle.load(gzip.open(TRAIN_MODIFIED_DIR + KFOLD_FILENAME, 'rb'))

for f in folds:
    print(len(f[0]), len(f[1]))
    
    count = 0
    for fname in f[0]:
        splits = fname.split('\\')
        label, uid = splits[-2], splits[-1].split('_')[0]
        if label == '_background_noise_':
            continue
        count += 1
    print(count)
    
    count = 0
    for fname in f[1]:
        splits = fname.split('\\')
        label, uid = splits[-2], splits[-1].split('_')[0]
        if label == '_background_noise_':
            continue
        count += 1
    print(count)
# Out:
# 53504 18717
# 47464
# 16410
# 53793 18428
# 47448
# 16426
# 54180 18041
# 47806
# 16068
# 55186 17035
# 48904
# 14970

# %%
from utilities import *
import pickle
import gzip

folds = pickle.load(gzip.open(TRAIN_MODIFIED_DIR + KFOLD_FILENAME, 'rb'))
trainset, valset = load_fold_my_noise(folds[0])
# Out:
# There are 47464 train and 16410 val samples
# Noise files:
# doing_the_dishes.wav
# dude_miaowing.wav
# exercise_bike.wav
# pink_noise.wav
# running_tap.wav
# white_noise.wav
# There are 51566 train and 17824 val samples after adding SILENCE

# %%
from utilities import *
import pickle
import gzip

folds = pickle.load(gzip.open(TRAIN_MODIFIED_DIR + MY_KFOLD_FILENAME, 'rb'))
trainset_my, valset_my = load_fold_my_noise(folds[0])
# Out:
# There are 47804 train and 16070 val samples
# Noise files:
# doing_the_dishes.wav
# dude_miaowing.wav
# exercise_bike.wav
# pink_noise.wav
# running_tap.wav
# white_noise.wav
# There are 51934 train and 17456 val samples after adding SILENCE

# %%
fnames = set()
for s in valset:
    if s[0] == NAME2ID['silence']:
        fnames.add(s[2])
print(fnames)
# Out:
# {'', 'C:/data/tf_speech/train/audio/_background_noise_/white_noise.wav', 'C:/data/tf_speech/train/audio/_background_noise_/running_tap.wav', 'C:/data/tf_speech/train/audio/_background_noise_/dude_miaowing.wav', 'C:/data/tf_speech/train/audio/_background_noise_/doing_the_dishes.wav', 'C:/data/tf_speech/train/audio/_background_noise_/exercise_bike.wav', 'C:/data/tf_speech/train/audio/_background_noise_/pink_noise.wav'}

# %%
from collections import Counter
count_train = Counter([s[0] for s in trainset_my])
for k in count_train.keys():
    print('{}:\t{},\t{}'.format(k, count_train[k], count_train[k] / len(trainset_my)))
# Out:
# 0:	1776,	0.034197250356221356
# 1:	1780,	0.03427427119035699
# 2:	1733,	0.0333692763892633
# 3:	1738,	0.03346555243193284
# 4:	1733,	0.0333692763892633
# 5:	1729,	0.03329225555512766
# 6:	1769,	0.034062463896484
# 7:	1763,	0.03394693264528055
# 8:	1748,	0.03365810451727192
# 9:	1759,	0.03386991181114492
# 10:	4130,	0.07952401124504178
# 11:	30276,	0.5829706935726114

# %%
valfiles = [v[2] for v in valset]
[f.split('\\')[-2] + '_' + f.split('\\')[-1] for f in valfiles]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-4d4568823d78> in <module>()
#       1 valfiles = [v[2] for v in valset]
# ----> 2 [f.split('\\')[-2] + '_' + f.split('\\')[-1] for f in valfiles]
#
# <ipython-input-23-4d4568823d78> in <listcomp>(.0)
#       1 valfiles = [v[2] for v in valset]
# ----> 2 [f.split('\\')[-2] + '_' + f.split('\\')[-1] for f in valfiles]
#
# IndexError: list index out of range

# %%
# Out:
# ['C:/data/tf_speech/train_modified/audio\\down\\00176480_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\00f0204f_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\014f9f65_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\01d22d03_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\037c445a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\03cf93b1_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\03cf93b1_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\0447d7c1_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\0447d7c1_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\0447d7c1_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\05b2db80_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\05b2db80_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\06076b6b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\06076b6b_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\06076b6b_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\079dfce3_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\07c5129e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\0819edb0_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\0819edb0_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\0819edb0_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\0819edb0_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\0b77ee66_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\0b77ee66_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\0b77ee66_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\0c2ca723_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\0fa1e7a9_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\10467b06_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\11321027_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\12529547_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\12529547_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\129c7d8d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\129c7d8d_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\151bfb79_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\15c371c7_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\15c563d7_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\15c563d7_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\15c563d7_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\15c563d7_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\15c563d7_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\1626bc5a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\1626bc5a_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\1657c9fa_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\16db1582_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\172dc2b0_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\172dc2b0_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\1a9afd33_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\1b755c65_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\1ffd513b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\1ffd513b_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\1ffd513b_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\1ffd513b_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\2197f41c_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\234ab0fb_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\234ab0fb_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\23ad12d8_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\23ad12d8_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\23ad12d8_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\24694eb6_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\24befdb3_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\24befdb3_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\24befdb3_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\24befdb3_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\24befdb3_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\24ed94ab_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\257e17e0_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\258f4559_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\258f4559_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\264f471d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\264f471d_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\264f471d_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\264f471d_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\264f471d_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\2796ac50_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\28ef2a01_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\28ef2a01_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\2903efb3_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\2aec99ec_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\2d92f18b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\2d92f18b_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\2d92f18b_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\2d92f18b_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\30137d34_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\30137d34_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\31270cb2_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3143fdff_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3143fdff_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\31d31fa0_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\31d31fa0_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3209ec42_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3209ec42_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\329eab8a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\329eab8a_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3367cff6_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3389305e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3411cf4b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\34263ab3_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\34263ab3_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3477fab6_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3565ca83_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\35c8fa78_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\363c6bad_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\363c6bad_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\365531e2_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3777c08e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\37dca74f_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\37dca74f_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\37dca74f_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\37dca74f_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3847619e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3847619e_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\39a12648_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\39a12648_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\39a12648_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\39a12648_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\39a12648_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\39a6b995_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\39a6b995_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3a70ab7f_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3aa6f4e2_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3aa6f4e2_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3b7f817e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3c1e12cf_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3c257192_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3c257192_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3c257192_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3c257192_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3c257192_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3c8836dc_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3cdecb0b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3da7f617_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3da7f617_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3e31dffe_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3e31dffe_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3e31dffe_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3e31dffe_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3e31dffe_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3ec05c3d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3ed3e49a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\3f339c33_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\408de0a4_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\41474817_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\422d3197_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\4290ca61_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\42ccb57a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\44c201dd_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\45864319_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\45864319_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\4845bb10_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\4845bb10_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\48a8a69d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\48a8a69d_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\48bfde8e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\48bfde8e_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\48bfde8e_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\48bfde8e_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\48bfde8e_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\49f30eed_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\4c77947d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\4c77947d_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\4c841771_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\4c841771_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\4def68db_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\4def68db_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\4def68db_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\4e8c5516_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\4f086393_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\50a7d406_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\50ed8a7b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\51055bda_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\51055bda_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\51055bda_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\51055bda_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\51055bda_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\5165cf0a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\5236848b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\528f9242_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\528f9242_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\528f9242_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\538e1856_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\53eb0a88_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\5628d7b7_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\563aa4e6_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\563aa4e6_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\563aa4e6_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\563aa4e6_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\563aa4e6_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\5744b6a7_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\5744b6a7_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\57b68383_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\590750e8_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\590750e8_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\5ba724a7_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\5c237956_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\5c237956_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\5e3dde6b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\5e3dde6b_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\5e3dde6b_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\5e3dde6b_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\5e3dde6b_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\5f1b1051_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6094340e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6094340e_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\611d2b50_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\611d2b50_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\611d2b50_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\611d2b50_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\611d2b50_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\61e50f62_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\61e50f62_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\625fd898_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\62641b88_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\638548d5_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6414258b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\64220627_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\64220627_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\65040d9b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\65079685_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\65079685_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6794a793_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\67961766_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\692a88e6_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\692a88e6_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\692a88e6_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\692a88e6_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\692a88e6_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\69f609ec_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6ac35824_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6adb8ad9_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6adb8ad9_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6c429c7b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6c429c7b_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6c429c7b_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6c429c7b_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6c968bd9_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6c968bd9_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6c968bd9_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6c968bd9_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6c968bd9_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6d0ad764_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6d2d3b0d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6d2d3b0d_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6d2d3b0d_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6d818f6c_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6fca237d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\6fca237d_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\708b8d51_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\71aa5b54_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\71aa5b54_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\7318280c_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\735845ab_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\735845ab_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\735845ab_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\735845ab_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\735845ab_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\750e3e75_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\750e3e75_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\76424fa5_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\76424fa5_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\76e53db9_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\784e281a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\784e281a_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\7bf801d1_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\7cbf645a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\7cbf645a_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\7fd25f7c_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\7fd25f7c_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\7fd25f7c_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\7fd25f7c_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\7fd25f7c_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\7ff085e1_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\7ff085e1_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\80b8eab4_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8134f43f_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8134f43f_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8134f43f_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8134f43f_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8134f43f_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\825f450d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\826268f8_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\826268f8_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8281a2a8_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8281a2a8_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8281a2a8_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8281a2a8_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8281a2a8_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\82e7204d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\82e7204d_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\833a0279_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\833a0279_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\840c366d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\840eab5a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\840eab5a_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\840eab5a_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\86402da1_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\86402da1_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\86402da1_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\881583a6_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\881583a6_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8843b25f_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\884ae8e1_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\884ae8e1_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\88f3719f_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8a194ee6_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8a194ee6_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8a194ee6_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8a194ee6_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8c7b691a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8c7c9168_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8d9cc260_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8d9cc260_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8e884ec4_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8eb4a1bf_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8eb4a1bf_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8eb4a1bf_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8eb4a1bf_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8eb4a1bf_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8f0d3c27_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8f4c551f_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8f4c551f_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8f4c551f_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8f4c551f_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\8f4c551f_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9080f6d3_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9080f6d3_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9080f6d3_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\92b0a735_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\95218ce8_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\96a48d28_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\96a48d28_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\96a48d28_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\96a48d28_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\96a48d28_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\96ab6565_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\96ab6565_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\96ab6565_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\96ab6565_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\96ab6565_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\96cd0255_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\96cd0255_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9712cce0_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\977a3be4_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\977a3be4_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9785931e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\97addd88_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\97f493b9_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\97f493b9_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\97f493b9_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9886d8bf_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9886d8bf_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9886d8bf_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9886d8bf_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9886d8bf_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\997867e7_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\997867e7_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9a43b64b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9a7c1f83_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9a7c1f83_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9a7c1f83_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9a7c1f83_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9aa5439d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9aa5439d_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9b5815cd_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9b5815cd_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9b5815cd_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9b5815cd_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9b5815cd_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9c59dd28_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9dc1889e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9dc1889e_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9e075bf1_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9efe5140_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9efe5140_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9efe5140_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9f63152b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9f7079fe_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\9f7079fe_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\a0f93943_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\a1533da4_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\a1533da4_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\a1dd919f_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\a2b16113_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\a2b16113_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\a3502f15_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\a4ca3afe_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\a6285644_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\a6285644_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\a7545b9f_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\a879a2c3_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\a879a2c3_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\a8e25ebb_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\a8ee11c7_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\a9f38bae_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\a9f38bae_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\a9f38bae_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\aa62fdad_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\ab5b211a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\ac652c60_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\ac7840d8_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\ad340ed7_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\af30314d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\afbec28d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b0c0197e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b52bd596_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b52bd596_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b575b5fb_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b575b5fb_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b5935410_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b5935410_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b5935410_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b59fa113_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b59fa113_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b7016c27_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b7a0754f_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b7a0754f_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b7a0754f_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b7a0754f_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b7a0754f_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b80d6c5e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b80d6c5e_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b83c1acf_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b83c1acf_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b83c1acf_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b83c1acf_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b83c1acf_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b843de62_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b9f46737_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b9f46737_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b9f46737_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b9f46737_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\b9f46737_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\baeac2ba_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\bc065a17_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\bca56796_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\bd11a2e7_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\bd11c654_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\bdb26021_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\bf70feda_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\bf70feda_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c0445658_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c0445658_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c0445658_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c0445658_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c0e0f834_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c0e0f834_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c0e8f5a1_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c0e8f5a1_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c137814b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c22d3f18_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c22d3f18_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c22d3f18_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c22d3f18_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c22d3f18_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c25a032b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c2e08f08_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c50225fa_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c79159aa_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c79159aa_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c79159aa_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c79159aa_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c79159aa_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c7b4049e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\c7b4049e_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\caa4779f_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\caa4779f_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\cab100c9_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\caedb73a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\cc71bada_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\cce17a61_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\cd3331a6_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\cd85758f_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\cd85758f_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\cd85758f_nohash_21095.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\cd85758f_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\cd85758f_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\cd911ace_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\cd911ace_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\ce49cb60_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\ce9410da_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\cf68fad2_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\d0858dce_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\d31d8dd7_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\d55aa56c_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\d57febf0_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\d6360b32_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\d6360b32_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\d6360b32_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\d71ad617_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\d71ad617_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\d7c60815_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\d84829e0_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\d8521ea0_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\d8521ea0_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\d85270c1_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\d85270c1_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\d952a17e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\d9b50b8b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\da1d320c_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\da1d320c_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\da4ef063_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\da7689f1_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\dabd70c2_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\dabd70c2_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\dabf67d9_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\daf230ac_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\daf230ac_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\db7c95b0_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\db7c95b0_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\db7c95b0_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\db8a3397_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\db8a3397_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\dca2797e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\dca2797e_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\dca2797e_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\dca2797e_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\dca2797e_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\dca6b373_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\dce5041a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\de040337_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\de08912f_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\de4f7798_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\de4f7798_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\dec73123_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\df038de4_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\df038de4_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e0322f2c_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e0344f60_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e04d7130_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e04d7130_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e10e2cbb_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e1469561_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e1469561_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e1469561_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e1469561_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e1469561_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e14a99a5_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e2362167_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e2362167_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e41a903b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e41a903b_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e41a903b_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e41a903b_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e41a903b_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e53139ad_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e53139ad_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e53139ad_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e53139ad_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e53139ad_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e5afa9b0_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e6be0830_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e7ea8b76_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e7ea8b76_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e7ea8b76_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e7ea8b76_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e7ea8b76_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\e7ea8b76_nohash_5.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\ea7ca285_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\ead2934a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\eb0676ec_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\eb0676ec_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\eb0676ec_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\eb0676ec_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\eb0676ec_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\eb609143_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\eb609143_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\eb609143_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\eb67fcbc_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\eb67fcbc_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\eb6dab4a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\eb6dab4a_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\ec545975_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\ec7d1151_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\ec7d1151_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\ec7d1151_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\ee4a907f_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\eefd26f3_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\ef2a3cfb_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f00180d0_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f15a354c_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f15a354c_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f15a354c_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f17be97f_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f17be97f_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f17be97f_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f17be97f_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f17be97f_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f19d1738_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f1d36c53_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f1d36c53_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f264e0df_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f264e0df_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f297e878_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f428ca69_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f4504600_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f5c3de1b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f5c3de1b_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f5e5e8b0_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f5e5e8b0_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f638a812_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f638a812_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f7b43563_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f9273a21_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f953e1af_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f953e1af_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f953e1af_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f953e1af_nohash_3741.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f953e1af_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f9bdf10e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\f9bdf10e_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\fac74f6a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\facd97c0_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\facd97c0_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\fad7a69a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\fad7a69a_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\fda46b78_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\fda46b78_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\fe5c4a7a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\down\\fe5c4a7a_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\00f0204f_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\00f0204f_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\014f9f65_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\01d22d03_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\01d22d03_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\01d22d03_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\037c445a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\03c96658_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\0447d7c1_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\05b2db80_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\06076b6b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\07c5129e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\07c5129e_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\07c5129e_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\0b77ee66_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\0b77ee66_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\0c2ca723_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\0c2ca723_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\0c2ca723_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\0fa1e7a9_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\0fa1e7a9_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\10467b06_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\10467b06_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\11321027_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\12529547_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\126403d4_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\129c7d8d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\135c6841_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\151bfb79_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\15b0c947_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\15b0c947_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\15b0c947_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\15c563d7_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\15c563d7_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\15c563d7_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\15c563d7_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\1626bc5a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\1657c9fa_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\16db1582_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\16db1582_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\172dc2b0_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\173ce2be_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\173ce2be_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\173e6bbf_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\173e6bbf_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\199da2bf_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\1bb574f9_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\1bb574f9_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\1bb6ed89_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\1bb6ed89_nohash_1.wav',
# ...
#  'C:/data/tf_speech/train_modified/audio\\go\\48a8a69d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\48bfde8e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\48e8b82a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\49f30eed_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\4a294341_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\4abefdf5_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\4c77947d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\4def68db_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\4f086393_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\50a7d406_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\50ed8a7b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\51055bda_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\51055bda_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\51055bda_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\51055bda_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\51055bda_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\52bfbce8_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\538e1856_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\541e4079_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\5628d7b7_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\5628d7b7_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\5628d7b7_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\563aa4e6_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\563aa4e6_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\563aa4e6_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\563aa4e6_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\563aa4e6_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\56f8a100_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\56f8a100_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\57b68383_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\590750e8_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\590750e8_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\590750e8_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\591d32f3_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\5ba724a7_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\5ba724a7_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\5c237956_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\5e3dde6b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\5e3dde6b_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\5e3dde6b_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\5e3dde6b_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\5e3dde6b_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\5eb5fc74_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\5eb5fc74_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\5f1b1051_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\611d2b50_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\611d2b50_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\611d2b50_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\611d2b50_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6166ae21_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\61e50f62_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\61e50f62_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\625fd898_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\625fd898_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\62641b88_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\62641b88_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6414258b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\64220627_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\64220627_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\64da5281_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\65040d9b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\682e1687_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\692a88e6_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\692a88e6_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\692a88e6_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\692a88e6_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\692a88e6_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\69f609ec_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\69f609ec_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6a203e0e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6ac35824_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6adb8ad9_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6adb8ad9_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6adb8ad9_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6c429c7b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6c429c7b_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6c429c7b_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6c429c7b_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6c429c7b_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6c968bd9_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6c968bd9_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6c968bd9_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6c968bd9_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6c968bd9_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6d0ad764_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6d2d3b0d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6d2d3b0d_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6d818f6c_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6d818f6c_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6dfff95a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6e916de8_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6f3458b3_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6f7724f5_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\6fca237d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\708b8d51_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\71aa5b54_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\7303215d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\7303215d_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\735845ab_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\735845ab_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\735845ab_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\735845ab_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\735845ab_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\76e53db9_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\78102205_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\784e281a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\784e281a_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\7bf801d1_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\7bf801d1_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\7cbf645a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\7cbf645a_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\7d86b703_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\7fd25f7c_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\7fd25f7c_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\7fd25f7c_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\7fd25f7c_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\80c17118_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\80fe1dc7_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8134f43f_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8134f43f_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8134f43f_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8134f43f_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8134f43f_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\824e8ce5_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\825f450d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\825f450d_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8281a2a8_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8281a2a8_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8281a2a8_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8281a2a8_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8281a2a8_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\86402da1_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\86402da1_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\881583a6_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\881583a6_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\884ae8e1_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8a194ee6_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8c7b691a_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8c7c9168_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8d9cc260_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8dc26a15_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8eb4a1bf_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8eb4a1bf_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8eb4a1bf_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8eb4a1bf_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8eb4a1bf_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8f0d3c27_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8f0d3c27_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8f4c551f_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8f4c551f_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8f4c551f_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8f4c551f_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\8f4c551f_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9080f6d3_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\919d3c0e_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\919d3c0e_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\919d3c0e_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9229bff9_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\93ec8b84_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\95218ce8_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\96a48d28_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\96a48d28_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\96a48d28_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\96a48d28_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\96a48d28_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\96ab6565_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\96ab6565_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\96ab6565_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\96ab6565_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\96ab6565_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\96cd0255_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9712cce0_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\977a3be4_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\97ae8b25_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\97ae8b25_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\97e0c576_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\97f493b9_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\97f493b9_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9886d8bf_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9886d8bf_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9886d8bf_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9886d8bf_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9886d8bf_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\989a2213_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\989a2213_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\997867e7_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\997867e7_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9a43b64b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9a43b64b_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9a7c1f83_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9a7c1f83_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9a7c1f83_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9a7c1f83_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9a7c1f83_nohash_4.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9aa5439d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9b027ecf_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9b027ecf_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9b027ecf_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9b027ecf_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9b6c08ba_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9beccfc8_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9beccfc8_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9e075bf1_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9efe5140_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9efe5140_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9f63152b_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9f63152b_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\9f63152b_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a0f93943_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a0f93943_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a0f93943_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a1533da4_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a1dd919f_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a2b16113_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a3502f15_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a3502f15_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a3502f15_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a3502f15_nohash_3.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a4ca3afe_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a591c2ea_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a7545b9f_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a879a2c3_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a879a2c3_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a879a2c3_nohash_2.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a8e25ebb_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a8ee11c7_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a8ee11c7_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\go\\a9f38bae_nohash_0.wav',
#  ...]

# %%
fnames = set()
for s in valset:
    if s[0] == NAME2ID['silence']:
        fnames.add(s[2])
print([f.split('/') for f in fnames])
# Out:
# [[''], ['C:', 'data', 'tf_speech', 'train', 'audio', '_background_noise_', 'white_noise.wav'], ['C:', 'data', 'tf_speech', 'train', 'audio', '_background_noise_', 'running_tap.wav'], ['C:', 'data', 'tf_speech', 'train', 'audio', '_background_noise_', 'dude_miaowing.wav'], ['C:', 'data', 'tf_speech', 'train', 'audio', '_background_noise_', 'doing_the_dishes.wav'], ['C:', 'data', 'tf_speech', 'train', 'audio', '_background_noise_', 'exercise_bike.wav'], ['C:', 'data', 'tf_speech', 'train', 'audio', '_background_noise_', 'pink_noise.wav']]

# %%
from utilities import *
import pickle
import gzip

folds = pickle.load(gzip.open(TRAIN_MODIFIED_DIR + MY_KFOLD_FILENAME, 'rb'))

for fold in folds:
    trainset, valset = load_fold_my_noise(fold)
    train_uids = [s[1] for s in trainset]
    val_uids = [s[1] for s in valset]
    
    print(val_uids[:10])
    
    for i in val_uids:
        if i != '' and i in train_uids:
            print('!!!: ', i)
# Out:
# There are 47804 train and 16070 val samples
# Noise files:
# doing_the_dishes.wav
# dude_miaowing.wav
# exercise_bike.wav
# pink_noise.wav
# running_tap.wav
# white_noise.wav
# There are 51854 train and 17432 val samples after adding SILENCE
# ['00176480', '00f0204f', '00f0204f', '0135f3f2', '02746d24', '03c96658', '0447d7c1', '060cd039', '060cd039', '0685264e']
# There are 48125 train and 15749 val samples
# Noise files:
# doing_the_dishes.wav
# dude_miaowing.wav
# exercise_bike.wav
# pink_noise.wav
# running_tap.wav
# white_noise.wav
# There are 52199 train and 17081 val samples after adding SILENCE
# ['0132a06d', '01648c51', '01648c51', '016e2c6d', '01bcfc0c', '035de8fe', '0362539c', '0362539c', '0397ecda', '05d18852']
# There are 47525 train and 16349 val samples
# Noise files:
# doing_the_dishes.wav
# dude_miaowing.wav
# exercise_bike.wav
# pink_noise.wav
# running_tap.wav
# white_noise.wav
# There are 51551 train and 17729 val samples after adding SILENCE
# ['012c8314', '012c8314', '0137b3f4', '014f9f65', '01b4757a', '01b4757a', '0227998e', '026290a7', '037c445a', '0474c92a']
# There are 48168 train and 15706 val samples
# Noise files:
# doing_the_dishes.wav
# dude_miaowing.wav
# exercise_bike.wav
# pink_noise.wav
# running_tap.wav
# white_noise.wav
# There are 52248 train and 17032 val samples after adding SILENCE
# ['004ae714', '004ae714', '042186b8', '042ea76c', '06076b6b', '063d48cf', '063d48cf', '0c2ca723', '0c2ca723', '0c2d2ffa']

# %% [markdown]
# # Create KFold with my noise. Other files - from my previous KFold

# %%
folds = pickle.load(gzip.open(TRAIN_MODIFIED_DIR + MY_KFOLD_FILENAME, 'rb'))

print('Without _background_noise_ files')
for f in folds:
    print(len(f[0]), len(f[1]))
    
    count = 0
    for fname in f[0]:
        splits = fname.split('\\')
        label, uid = splits[-2], splits[-1].split('_')[0]
        if label == '_background_noise_':
            continue
        count += 1
    print('Train: ', count)
    
    count_val = 0
    for fname in f[1]:
        splits = fname.split('\\')
        label, uid = splits[-2], splits[-1].split('_')[0]
        if label == '_background_noise_':
            continue
        count += 1
        count_val += 1
    print('Val: ', count_val)
    print('Total: ', count)
    print('-----------------')
n_samples = count
# Out:
# Without _background_noise_ files
# 54171 18056
# Train:  47804
# Val:  16070
# Total:  63874
# -----------------
# 54556 17671
# Train:  48125
# Val:  15749
# Total:  63874
# -----------------
# 53922 18305
# Train:  47525
# Val:  16349
# Total:  63874
# -----------------
# 54599 17628
# Train:  48168
# Val:  15706
# Total:  63874
# -----------------

# %%
BG_MODIFIED_DIR = TRAIN_MODIFIED_DIR + 'audio\\_background_noise_\\'

def load_bg_noises():
    bg_files = os.listdir(BG_DIR)
    bg_files.remove('README.md')
    bg_files = [os.path.join(BG_MODIFIED_DIR, f) for f in bg_files]
    print(bg_files)
    bg_wavs = []
    for bg_file in bg_files:
        _, wav = wavfile.read(bg_file)
        bg_wavs.append(wav)
    return bg_wavs, bg_files

bg_wavs, bg_files = load_bg_noises()
# Out:
# ['C:/data/tf_speech/train_modified/audio\\_background_noise_\\doing_the_dishes.wav', 'C:/data/tf_speech/train_modified/audio\\_background_noise_\\dude_miaowing.wav', 'C:/data/tf_speech/train_modified/audio\\_background_noise_\\exercise_bike.wav', 'C:/data/tf_speech/train_modified/audio\\_background_noise_\\pink_noise.wav', 'C:/data/tf_speech/train_modified/audio\\_background_noise_\\running_tap.wav', 'C:/data/tf_speech/train_modified/audio\\_background_noise_\\white_noise.wav']
# C:\Users\MAX\Anaconda2\envs\tf\lib\site-packages\scipy\io\wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)

# %%
for w in bg_wavs:
    print(w.dtype)
# Out:
# int16
# int16
# int16
# int16
# int16
# int16

# %%
noise_type_percent = (SILENCE_PERCENT / (1 - SILENCE_PERCENT)) / (len(bg_wavs) + 1)
n_noise_type = int(noise_type_percent * n_samples)
print('Adding', n_noise_type, 'samples for each noise file')
# Out:
# Adding 902 samples for each noise file

# %%
new_bg_wavs = []
new_bg_files = []

for wav, f in zip(bg_wavs, bg_files):
    count = 0
    f_splits = f.split('.')
    for i in range(n_noise_type):
        i = np.random.randint(0, len(wav) - LENGTH)
        new_wav = wav[i : i + LENGTH]
        new_bg_wavs.append(new_wav)
        new_f = f_splits[-2] + '_{}.'.format(count) + f_splits[-1]
        new_bg_files.append(new_f)
        wavfile.write(new_f, LENGTH, new_wav)
        count += 1

# %%
new_bg_files = np.array(new_bg_files)

# %%
new_bg_files
# Out:
# array(['C:/data/tf_speech/train_modified/audio/_background_noise_/doing_the_dishes_0.wav',
#        'C:/data/tf_speech/train_modified/audio/_background_noise_/doing_the_dishes_1.wav',
#        'C:/data/tf_speech/train_modified/audio/_background_noise_/doing_the_dishes_2.wav',
#        ...,
#        'C:/data/tf_speech/train_modified/audio/_background_noise_/white_noise_899.wav',
#        'C:/data/tf_speech/train_modified/audio/_background_noise_/white_noise_900.wav',
#        'C:/data/tf_speech/train_modified/audio/_background_noise_/white_noise_901.wav'],
#       dtype='<U82')

# %%
new_bg_files = glob.glob(os.path.join(BG_MODIFIED_DIR, '*wav'))
print(len(new_bg_files))
new_bg_files.remove('C:/data/tf_speech/train_modified/audio\\_background_noise_\\doing_the_dishes.wav')
new_bg_files.remove('C:/data/tf_speech/train_modified/audio\\_background_noise_\\dude_miaowing.wav')
new_bg_files.remove('C:/data/tf_speech/train_modified/audio\\_background_noise_\\exercise_bike.wav')
new_bg_files.remove('C:/data/tf_speech/train_modified/audio\\_background_noise_\\pink_noise.wav')
new_bg_files.remove('C:/data/tf_speech/train_modified/audio\\_background_noise_\\running_tap.wav')
new_bg_files.remove('C:/data/tf_speech/train_modified/audio\\_background_noise_\\white_noise.wav')
print(len(new_bg_files))
new_bg_files = np.array(new_bg_files)
# Out:
# 5418
# 5412

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=17)
bg_folds = []
for train_index, test_index in kf.split(new_bg_files):
    bg_folds.append([new_bg_files[train_index], new_bg_files[test_index]])

# %%
for bg_fold in bg_folds:
    for f in bg_fold[0]:
        if f in bg_fold[1]:
            print('!!!: ', f)

# %%
old_folds = pickle.load(gzip.open(TRAIN_MODIFIED_DIR + MY_KFOLD_FILENAME, 'rb'))
new_folds = []

for i, f in enumerate(old_folds):
    print(len(f[0]), len(f[1]))
    new_f_train = []
    new_f_val = []
    
    for fname in f[0]:
        splits = fname.split('\\')
        label, uid = splits[-2], splits[-1].split('_')[0]
        if label != '_background_noise_':
            new_f_train.append(fname)

    for fname in f[1]:
        splits = fname.split('\\')
        label, uid = splits[-2], splits[-1].split('_')[0]
        if label != '_background_noise_':
            new_f_val.append(fname)

    for fname in bg_folds[i][0]:
        new_f_train.append(fname)
        
    for fname in bg_folds[i][1]:
        new_f_val.append(fname)
    
    new_folds.append([new_f_train, new_f_val])
# Out:
# 54171 18056
# 54556 17671
# 53922 18305
# 54599 17628

# %%
for f in new_folds:
    print(len(f[0]), len(f[1]))
# Out:
# 51863 17423
# 52184 17102
# 51584 17702
# 52227 17059

# %%
from utilities import *
import pickle
import gzip

with gzip.open(TRAIN_MODIFIED_DIR + 'kfold4_max_new_noise.pklz', 'wb') as f:
    pickle.dump(new_folds, f)

# %%
MY_KFOLD_NOISE_FILENAME = 'kfold4_max_new_noise.pklz'

old_folds = pickle.load(gzip.open(TRAIN_MODIFIED_DIR + MY_KFOLD_FILENAME, 'rb'))
new_folds = pickle.load(gzip.open(TRAIN_MODIFIED_DIR + MY_KFOLD_NOISE_FILENAME, 'rb'))

# %%
new_folds[0][0][:10]
# Out:
# ['C:/data/tf_speech/train_modified/audio\\bed\\004ae714_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\bed\\004ae714_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\bed\\012c8314_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\bed\\012c8314_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\bed\\0132a06d_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\bed\\0137b3f4_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\bed\\014f9f65_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\bed\\01648c51_nohash_0.wav',
#  'C:/data/tf_speech/train_modified/audio\\bed\\01648c51_nohash_1.wav',
#  'C:/data/tf_speech/train_modified/audio\\bed\\016e2c6d_nohash_0.wav']

# %%
new_folds[0][0][-10:]
# Out:
# ['C:/data/tf_speech/train_modified/audio\\_background_noise_\\white_noise_9.wav',
#  'C:/data/tf_speech/train_modified/audio\\_background_noise_\\white_noise_901.wav',
#  'C:/data/tf_speech/train_modified/audio\\_background_noise_\\white_noise_91.wav',
#  'C:/data/tf_speech/train_modified/audio\\_background_noise_\\white_noise_92.wav',
#  'C:/data/tf_speech/train_modified/audio\\_background_noise_\\white_noise_93.wav',
#  'C:/data/tf_speech/train_modified/audio\\_background_noise_\\white_noise_94.wav',
#  'C:/data/tf_speech/train_modified/audio\\_background_noise_\\white_noise_95.wav',
#  'C:/data/tf_speech/train_modified/audio\\_background_noise_\\white_noise_96.wav',
#  'C:/data/tf_speech/train_modified/audio\\_background_noise_\\white_noise_97.wav',
#  'C:/data/tf_speech/train_modified/audio\\_background_noise_\\white_noise_98.wav']

# %%
for i, f in enumerate(old_folds):
    for fname in f[0]:
        splits = fname.split('\\')
        label, uid = splits[-2], splits[-1].split('_')[0]
        if label != '_background_noise_':
            assert fname in new_folds[i][0]
            assert fname not in new_folds[i][1]
            
    for fname in f[1]:
        splits = fname.split('\\')
        label, uid = splits[-2], splits[-1].split('_')[0]
        if label != '_background_noise_':
            assert fname not in new_folds[i][0]
            assert fname in new_folds[i][1]

# %%
len(new_folds[0][0])
# Out:
# 51863

# %%
fold = new_folds[0]
train_files = [f.split('\\')[-2] + f.split('\\')[-1] for f in fold[0]]
val_files = [f.split('\\')[-2] + f.split('\\')[-1] for f in fold[1]]

# %%
val_files[-10:]
# Out:
# ['_background_noise_white_noise_868.wav',
#  '_background_noise_white_noise_872.wav',
#  '_background_noise_white_noise_874.wav',
#  '_background_noise_white_noise_880.wav',
#  '_background_noise_white_noise_882.wav',
#  '_background_noise_white_noise_883.wav',
#  '_background_noise_white_noise_890.wav',
#  '_background_noise_white_noise_90.wav',
#  '_background_noise_white_noise_900.wav',
#  '_background_noise_white_noise_99.wav']

# %%
new_folds = pickle.load(gzip.open(TRAIN_MODIFIED_DIR + MY_KFOLD_NOISE_FILENAME, 'rb'))

# %%
for i, f in enumerate(new_folds):
    val_labels = []
    for fname in f[1]:
        splits = fname.split('\\')
        label, uid = splits[-2], splits[-1].split('_')[0]
        val_labels.append(label)
    print(np.unique(val_labels, return_counts=True))
# Out:
# (array(['_background_noise_', 'bed', 'bird', 'cat', 'dog', 'down', 'eight',
#        'five', 'four', 'go', 'happy', 'house', 'left', 'marvin', 'nine',
#        'no', 'off', 'on', 'one', 'right', 'seven', 'sheila', 'six',
#        'stop', 'three', 'tree', 'two', 'up', 'wow', 'yes', 'zero'],
#       dtype='<U18'), array([1986,  431,  446,  464,  453,  591,  609,  601,  573,  574,  454,
#         437,  582,  458,  568,  567,  558,  555,  606,  591,  586,  437,
#         564,  599,  558,  419,  577,  590,  465,  574,  583], dtype=int64))
# (array(['_background_noise_', 'bed', 'bird', 'cat', 'dog', 'down', 'eight',
#        'five', 'four', 'go', 'happy', 'house', 'left', 'marvin', 'nine',
#        'no', 'off', 'on', 'one', 'right', 'seven', 'sheila', 'six',
#        'stop', 'three', 'tree', 'two', 'up', 'wow', 'yes', 'zero'],
#       dtype='<U18'), array([1922,  442,  431,  415,  428,  571,  539,  562,  579,  597,  427,
#         419,  561,  444,  579,  578,  578,  595,  568,  538,  582,  437,
#         603,  586,  548,  475,  570,  538,  416,  567,  576], dtype=int64))
# (array(['_background_noise_', 'bed', 'bird', 'cat', 'dog', 'down', 'eight',
#        'five', 'four', 'go', 'happy', 'house', 'left', 'marvin', 'nine',
#        'no', 'off', 'on', 'one', 'right', 'seven', 'sheila', 'six',
#        'stop', 'three', 'tree', 'two', 'up', 'wow', 'yes', 'zero'],
#       dtype='<U18'), array([1956,  404,  427,  442,  435,  608,  593,  606,  609,  616,  410,
#         434,  616,  395,  601,  627,  634,  590,  592,  618,  590,  428,
#         588,  611,  592,  412,  605,  585,  447,  619,  615], dtype=int64))
# (array(['_background_noise_', 'bed', 'bird', 'cat', 'dog', 'down', 'eight',
#        'five', 'four', 'go', 'happy', 'house', 'left', 'marvin', 'nine',
#        'no', 'off', 'on', 'one', 'right', 'seven', 'sheila', 'six',
#        'stop', 'three', 'tree', 'two', 'up', 'wow', 'yes', 'zero'],
#       dtype='<U18'), array([1922,  434,  418,  405,  425,  559,  575,  559,  581,  546,  438,
#         455,  556,  429,  576,  575,  551,  584,  569,  573,  578,  418,
#         569,  551,  567,  457,  587,  610,  406,  590,  565], dtype=int64))

# %%
MY_KFOLD_NOISE_FILENAME = 'kfold4_max_new_noise.pklz'

new_folds = pickle.load(gzip.open(TRAIN_MODIFIED_DIR + MY_KFOLD_NOISE_FILENAME, 'rb'))

for i, f in enumerate(new_folds):
    val_labels = []
    for fname in f[1]:
        splits = fname.split('\\')
        label, uid = splits[-2], splits[-1].split('_')[0]
        if label =='_background_noise_':
            label = 'silence'
        if label not in LABELS:
            label = 'unknown'
        
        val_labels.append(label)
    val, c = np.unique(val_labels, return_counts=True)
    
    print('Fold:', i, len(f[0]), len(f[1]))
    print(val)
    print(c)
    print(np.sum(c))
# Out:
# Fold: 0 51863 17423
# ['down' 'go' 'left' 'no' 'off' 'on' 'right' 'silence' 'stop' 'unknown'
#  'up' 'yes']
# [  591   574   582   567   558   555   591  1353   599 10289   590   574]
# 17423
# Fold: 1 52184 17102
# ['down' 'go' 'left' 'no' 'off' 'on' 'right' 'silence' 'stop' 'unknown'
#  'up' 'yes']
# [  571   597   561   578   578   595   538  1353   586 10040   538   567]
# 17102
# Fold: 2 51584 17702
# ['down' 'go' 'left' 'no' 'off' 'on' 'right' 'silence' 'stop' 'unknown'
#  'up' 'yes']
# [  608   616   616   627   634   590   618  1353   611 10225   585   619]
# 17702
# Fold: 3 52227 17059
# ['down' 'go' 'left' 'no' 'off' 'on' 'right' 'silence' 'stop' 'unknown'
#  'up' 'yes']
# [  559   546   556   575   551   584   573  1353   551 10011   610   590]
# 17059

# %%
trainset, valset = load_fold_my_noise(old_folds)
