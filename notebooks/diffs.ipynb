# %%
import pickle
import gzip
import numpy as np

INPUT_DIR = '../input/'
OUTPUT_DIR = '../output/'
MAIN_DIR = 'C:/data/tf_speech/'
TRAIN_DIR = MAIN_DIR + 'train/'
TRAIN_MODIFIED_DIR = MAIN_DIR + 'train_modified/'
TRAIN_AUDIO_DIR = TRAIN_DIR + 'audio/'
BG_DIR = TRAIN_DIR + 'audio/_background_noise_/'
TEST_DIR = MAIN_DIR + 'test/audio/'
PREDS_DIR = '../output/preds/'
KFOLD_FILENAME = 'kfold_cache_4.pklz'

folds = pickle.load(gzip.open(TRAIN_MODIFIED_DIR + KFOLD_FILENAME, 'rb'))
for f in folds:
    print (len(f[0]), len(f[1]))

# %%
folds[0][0][:10]

# %%
import os
import glob
from utilities import *
from tqdm import tqdm, tqdm_notebook

def load_fold(fold):
    train_files = [f.split('\\')[-2] + f.split('\\')[-1] for f in fold[0]]
    val_files = [f.split('\\')[-2] + f.split('\\')[-1] for f in fold[1]]
    
    all_files = glob.glob(os.path.join(TRAIN_MODIFIED_AUDIO_DIR, '*/*wav'))

    train, val = [], []
    for fname in tqdm(all_files):
        splits = fname.split('\\')
        label, uid = splits[-2], splits[-1].split('_')[0]
        if label == '_background_noise_':
            label = 'silence'
        if label not in LABELS:
            label = 'unknown'

        label_id = NAME2ID[label]

        sample = (label_id, uid, fname)
        sample_id = splits[-2] + splits[-1]
        if sample_id in val_files:
            val.append(sample)
        elif sample_id in train_files:
            train.append(sample)
    print('There are {} train and {} val samples'.format(len(train), len(val)))

    return train, val

trainset, valset = load_fold(folds[0])
trainset, valset = load_fold(folds[1])
trainset, valset = load_fold(folds[2])
trainset, valset = load_fold(folds[3])

# %%
trainset, valset = load_fold(folds[0])

# %%
files = ['../output/preds/r50_f/fold_0/train.csv',
        '../output/preds/r50_f/fold_1/train.csv',
         '../output/preds/r50_f/fold_2/train.csv',
         '../output/preds/r50_f/fold_3/train.csv',
        ]

trainset0, valset0 = load_fold(folds[0])
trainset1, valset1 = load_fold(folds[1])
trainset2, valset2 = load_fold(folds[2])
trainset3, valset3 = load_fold(folds[3])

labels = []
for valset in [valset0, valset1, valset2, valset3]:
    labels.append([v[0] for v in valset])

# %%
labels = [item for sublist in labels for item in sublist]

# %%
len(labels)
# Out:
# 72221

# %%
preds = []
for f in files:
    preds.append(pd.read_csv(f, index_col='fname').values)

# %%
preds = [item for sublist in preds for item in sublist]

# %%
preds = np.array(preds)

# %%
preds.shape
# Out:
# (72221, 12)

# %%
preds
# Out:
# array([[5.45341440e-07, 1.12733570e-02, 5.68119200e-09, ...,
#         5.33063660e-04, 1.10157160e-06, 8.19366130e-04],
#        [3.07502160e-05, 4.20786740e-02, 1.83860070e-07, ...,
#         1.01446700e-02, 4.59887670e-05, 4.46214970e-02],
#        [1.19450780e-04, 1.40774030e-02, 1.34401860e-03, ...,
#         2.29340960e-02, 5.63298500e-03, 4.74986100e-01],
#        ...,
#        [2.74742580e-04, 8.54635440e-05, 8.02750400e-06, ...,
#         6.07135100e-04, 9.98027400e-01, 5.09377200e-04],
#        [1.49946390e-05, 3.99721700e-05, 1.28649670e-05, ...,
#         3.90805070e-04, 9.98484700e-01, 8.63943800e-04],
#        [4.91329900e-04, 1.03470775e-05, 3.34988200e-06, ...,
#         5.97465260e-04, 5.93591750e-01, 3.91461520e-01]])

# %%
pred_labels = np.argmax(preds, axis=1)
pred_labels.shape
# Out:
# (72221,)

# %%
from sklearn.metrics import log_loss, accuracy_score, confusion_matrix

conf = confusion_matrix(labels, pred_labels)
for l in LABELS:
    total = sum(conf[NAME2ID[l]])
    acc = 1.0 * conf[NAME2ID[l], NAME2ID[l]] / total
    print('{}, total: {}, accuracy: {}'.format(l, total,  acc))
# Out:
# yes, total: 2350, accuracy: 0.9829787234042553
# no, total: 2347, accuracy: 0.9190455901150405
# up, total: 2323, accuracy: 0.9130434782608695
# down, total: 2329, accuracy: 0.8634607127522542
# left, total: 2315, accuracy: 0.9520518358531318
# right, total: 2320, accuracy: 0.8939655172413793
# on, total: 2324, accuracy: 0.898881239242685
# off, total: 2321, accuracy: 0.950021542438604
# stop, total: 2347, accuracy: 0.9203238176395399
# go, total: 2333, accuracy: 0.911701671667381
# silence, total: 8347, accuracy: 0.9595064094884389
# unknown, total: 40565, accuracy: 0.7977320350055467

# %% [markdown]
# ### diff

# %%
import pandas as pd
from utilities import *
# diff -y --suppress-common-lines a b | grep '^' | wc -l
def diff_preds(f1, f2):
    p1 = pd.read_csv(f1).label.values
    p2 = pd.read_csv(f2).label.values
    
#     for i in range(len(p1)):
#         if p1[i] != p2[i]:
#             print (p1[i], p2[i])
    return sum(p1 != p2)

def diff_preds2(f1, f2):
    p1 = pd.read_csv(f1, index_col='fname').values
    fnames = pd.read_csv(f1, index_col='fname').index
    p1 = np.argmax(p1, axis=1)
    p2 = pd.read_csv(f2).label.values
    p1 = [ID2NAME[i] for i in p1]
    
    for i in range(len(p1)):
        if p1[i] != p2[i]:
            print (fnames[i], p1[i], p2[i])
    return sum(p1 != p2)

# %%
print(diff_preds2('../output/preds/inc_139_my.csv', '../output/subm_majorty.csv'))
# Out:
# clip_0003c7122.wav silence unknown
# clip_0004c6707.wav silence go
# clip_00123c913.wav silence unknown
# clip_00139d600.wav off unknown
# clip_00178d644.wav unknown no
# clip_0018489ca.wav silence unknown
# clip_0018ff8e9.wav silence unknown
# clip_0023f6e02.wav no down
# clip_0025e94de.wav unknown right
# clip_0028ebc99.wav no unknown
# clip_00291e83c.wav silence unknown
# clip_002ddecb8.wav down no
# clip_0030a3206.wav stop up
# clip_0032d1f14.wav unknown left
# clip_0033aedac.wav unknown go
# clip_0034311e1.wav silence unknown
# clip_003e10edb.wav off unknown
# clip_004348a2b.wav silence unknown
# clip_0044f8416.wav unknown silence
# clip_004afbd03.wav silence unknown
# clip_004cc2e62.wav silence unknown
# clip_004d8390a.wav silence unknown
# clip_005e71a11.wav silence unknown
# clip_005f62fc3.wav unknown no
# clip_0066e2e7e.wav silence unknown
# clip_006b6248b.wav no go
# clip_006c084dc.wav silence unknown
# clip_0077e66de.wav silence unknown
# clip_007b5eb43.wav unknown silence
# clip_02247d5a2.wav silence unknown
# clip_02280e900.wav unknown right
# clip_0232bf954.wav off unknown
# clip_023bbb1fc.wav unknown left
# clip_023dc12d0.wav unknown right
# clip_023ef8d3c.wav silence unknown
# clip_024841ee7.wav up off
# clip_024a04869.wav silence unknown
# clip_026b0dfc3.wav unknown yes
# clip_026c29bc7.wav unknown off
# clip_0276ba884.wav unknown silence
# clip_0276d9c75.wav unknown silence
# clip_027a9207c.wav silence unknown
# clip_027f4a4c6.wav unknown go
# clip_028871d35.wav silence unknown
# clip_028ccc4ef.wav silence unknown
# clip_0294cf838.wav stop up
# clip_029563277.wav unknown no
# clip_029736e8e.wav no go
# clip_029ff73a2.wav silence unknown
# clip_02a1feff4.wav unknown up
# clip_02ae83461.wav silence on
# clip_02afc419f.wav unknown go
# clip_02afee959.wav unknown silence
# clip_02b2dfe8a.wav unknown silence
# clip_02b6ac07a.wav on unknown
# clip_02b810c64.wav silence unknown
# clip_02b9ab03b.wav on unknown
# clip_02b9c671e.wav unknown silence
# clip_02bc9c206.wav right unknown
# clip_02bcf2100.wav unknown silence
# clip_02bf4130c.wav silence unknown
# clip_02c0d767d.wav unknown left
# clip_02c24c569.wav unknown right
# clip_02c5a4801.wav silence unknown
# clip_02c6afe63.wav unknown no
# clip_02cbb4a6b.wav silence unknown
# clip_02cd88ff4.wav unknown no
# clip_02d00b6e8.wav silence unknown
# clip_02d13348b.wav go down
# clip_02d435a12.wav unknown silence
# clip_02e2c4494.wav unknown on
# clip_02e4fc260.wav up go
# clip_02e73c46f.wav silence unknown
# clip_02ed514f8.wav silence unknown
# clip_02f4d73d4.wav stop unknown
# clip_02fdca644.wav unknown silence
# clip_02fe225cf.wav unknown silence
# clip_0301087e7.wav silence unknown
# clip_0301a5621.wav left unknown
# clip_03022b2a6.wav unknown no
# clip_0304f6a0b.wav silence unknown
# clip_030a23d69.wav on unknown
# clip_030b6e25f.wav unknown on
# clip_030c9a97b.wav unknown go
# clip_030de6108.wav silence unknown
# clip_03108dde0.wav unknown silence
# clip_031596197.wav left unknown
# clip_03198a916.wav silence unknown
# clip_031a11150.wav unknown on
# clip_031fe4f96.wav unknown silence
# clip_0323b0245.wav off on
# clip_032edac97.wav silence unknown
# clip_0338560a7.wav left yes
# clip_0339f958b.wav silence unknown
# clip_033c1f1a0.wav unknown right
# clip_033d53d2c.wav unknown off
# clip_034fc8a8f.wav unknown silence
# clip_0350e1272.wav unknown silence
# clip_035205435.wav unknown on
# clip_03540524a.wav right unknown
# clip_035a2a9a1.wav silence unknown
# clip_035a545fd.wav left no
# clip_035b6c68f.wav yes no
# clip_035ba2fdd.wav silence unknown
# clip_035d2ec0b.wav unknown silence
# clip_035e94150.wav silence unknown
# clip_03608aa51.wav unknown on
# clip_036ec6892.wav unknown silence
# clip_036f62d0c.wav unknown silence
# clip_0374f26bb.wav silence unknown
# clip_0375a61aa.wav no go
# clip_0375f14d5.wav no unknown
# clip_037c38f2f.wav silence unknown
# clip_04d3efef6.wav silence unknown
# clip_04d71a0e3.wav unknown silence
# clip_04d8143db.wav silence unknown
# clip_04e1f26d3.wav silence unknown
# clip_04e2cca94.wav unknown left
# clip_04e6aa357.wav silence unknown
# clip_04e7a4046.wav unknown go
# clip_04f10ec40.wav silence unknown
# clip_04f712d03.wav silence unknown
# clip_04f742305.wav silence unknown
# clip_04facb3ee.wav unknown silence
# clip_04fcbf5e4.wav unknown off
# clip_05006228e.wav silence unknown
# clip_0504e9f70.wav silence unknown
# clip_0507ed201.wav unknown silence
# clip_0514ae013.wav unknown silence
# clip_0516bab84.wav unknown go
# clip_051742513.wav unknown stop
# clip_0518bbf4f.wav unknown go
# clip_052abc9ec.wav unknown up
# clip_052b57ae4.wav silence unknown
# clip_0532161f2.wav silence unknown
# clip_0534abcf6.wav unknown go
# clip_05355022f.wav silence unknown
# clip_0535a9890.wav unknown silence
# clip_053ab8f31.wav unknown no
# clip_053ad279f.wav silence go
# clip_053c8d1e1.wav silence unknown
# clip_053ed57ff.wav off up
# clip_054d3e6f6.wav no unknown
# clip_05512fd3f.wav left unknown
# clip_0553d4806.wav silence go
# clip_0555a2f80.wav silence unknown
# clip_05583f503.wav silence unknown
# clip_0558f4087.wav go down
# clip_055982ba1.wav left no
# clip_055c48aa8.wav unknown down
# clip_055d7d11a.wav unknown silence
# clip_056092623.wav silence unknown
# clip_056684427.wav unknown go
# clip_056ab2b7a.wav stop off
# clip_056b05bc0.wav silence unknown
# clip_057286bbc.wav silence unknown
# clip_057d73891.wav off on
# clip_05811924b.wav silence unknown
# clip_058a60a80.wav down no
# clip_058c322f1.wav silence go
# clip_059074002.wav off unknown
# clip_0591a009c.wav silence unknown
# clip_0591b4752.wav silence unknown
# clip_0591c87ee.wav silence unknown
# clip_0595b8dae.wav unknown silence
# clip_059b4604d.wav on unknown
# clip_059b98930.wav silence unknown
# clip_05a582293.wav silence unknown
# clip_05ab4a419.wav unknown off
# clip_05ac41bef.wav unknown right
# clip_05ad6831f.wav silence unknown
# clip_05b41770c.wav unknown silence
# clip_05b5eba66.wav unknown silence
# clip_05be2ce23.wav silence unknown
# clip_05bfe5e6a.wav unknown yes
# clip_05c07a582.wav silence unknown
# clip_05c4028de.wav silence unknown
# clip_05cb6ee77.wav silence unknown
# clip_05cd6bf28.wav silence unknown
# clip_05cfd7ec8.wav silence unknown
# clip_05d2732ca.wav silence unknown
# clip_05d99dd73.wav unknown no
# clip_05dba675d.wav unknown silence
# clip_05dc1e681.wav silence unknown
# clip_05dcb337d.wav unknown left
# clip_05e030985.wav unknown go
# clip_05e6ad958.wav silence unknown
# clip_05fe4b92d.wav unknown on
# clip_06060c4aa.wav silence unknown
# clip_060f44155.wav off on
# clip_060fa077f.wav silence unknown
# clip_06129664e.wav silence go
# clip_0616e1456.wav unknown silence
# clip_061736c41.wav silence unknown
# clip_061770c71.wav stop unknown
# clip_0617938f8.wav silence unknown
# clip_0618f2fd0.wav unknown go
# clip_061949e8c.wav unknown silence
# clip_0623e0ed7.wav silence unknown
# clip_06246c1d7.wav unknown silence
# clip_0628d1d9d.wav silence unknown
# clip_062befae5.wav silence unknown
# clip_0639aa648.wav silence unknown
# clip_0643abad2.wav unknown no
# clip_064544071.wav off on
# clip_064890cb4.wav silence unknown
# clip_064c1a660.wav silence unknown
# clip_065676279.wav go up
# clip_0657b5cf0.wav silence unknown
# clip_065856b8b.wav unknown no
# clip_065b86c08.wav no unknown
# clip_065b95335.wav unknown go
# clip_065edd916.wav unknown silence
# clip_06615eb41.wav unknown left
# clip_066360fd3.wav unknown up
# clip_0663a87c9.wav silence unknown
# clip_0665b9589.wav silence go
# clip_0676d76c4.wav left no
# clip_068eba54a.wav unknown go
# clip_069c17550.wav go no
# clip_06a0f7a8b.wav unknown go
# clip_06ab7a859.wav unknown silence
# clip_06b70d098.wav unknown down
# clip_06b77b93a.wav unknown off
# clip_06b968f6e.wav on off
# clip_06c150158.wav silence unknown
# clip_06c2bfd1e.wav unknown silence
# clip_06cd9c5dd.wav silence unknown
# clip_06d05e5d1.wav silence unknown
# clip_06d363eb8.wav unknown left
# clip_06d6addb9.wav no unknown
# clip_06d7de182.wav silence yes
# clip_06da69e2c.wav silence go
# clip_06df65b8c.wav unknown down
# clip_06e532b07.wav unknown no
# clip_06e92f046.wav silence unknown
# clip_06e967ffb.wav silence unknown
# clip_06f0a4966.wav unknown off
# clip_06f2dd902.wav unknown go
# clip_06f320506.wav no go
# clip_06f3a12e1.wav silence unknown
# clip_06f84e1da.wav silence unknown
# clip_070123ef3.wav up unknown
# clip_070163854.wav silence unknown
# clip_0704bc2ed.wav silence unknown
# clip_07062dffc.wav unknown down
# clip_070782418.wav silence unknown
# clip_070b77a69.wav silence unknown
# clip_070d79896.wav yes left
# clip_070e40f19.wav left up
# clip_070f0407f.wav no unknown
# clip_07151f948.wav silence unknown
# clip_071d42c0e.wav silence go
# clip_071df2f4d.wav silence unknown
# clip_072245c25.wav silence unknown
# clip_0726bf3d2.wav silence unknown
# clip_072a9f17f.wav silence unknown
# clip_072e54098.wav silence unknown
# clip_072ef8209.wav left unknown
# clip_072fc5682.wav silence unknown
# clip_073eb2e46.wav no down
# clip_07415966b.wav off up
# clip_0743abe0a.wav silence unknown
# clip_074661f75.wav silence unknown
# clip_0747e75b6.wav silence unknown
# clip_074c1a6ee.wav on unknown
# clip_0753ee07f.wav unknown silence
# clip_075ba3778.wav silence unknown
# clip_075c0dcdc.wav left unknown
# clip_076036eb9.wav unknown silence
# clip_0764e57a0.wav down no
# clip_0766ebb35.wav go down
# clip_077103162.wav silence unknown
# clip_07732cf49.wav no unknown
# clip_0777861d7.wav silence unknown
# clip_0778e6815.wav no down
# clip_077d1c5c1.wav silence unknown
# clip_077e9c84d.wav unknown no
# clip_078a62039.wav up off
# clip_078ef7f23.wav silence unknown
# clip_079323e33.wav unknown silence
# clip_0798b7009.wav unknown go
# clip_079f52920.wav up left
# clip_079fe0f32.wav silence unknown
# clip_07b25b798.wav unknown off
# clip_07c44faa3.wav silence unknown
# clip_07c51ed69.wav silence unknown
# clip_07c71c83f.wav silence unknown
# clip_07ce26648.wav silence unknown
# clip_07d228f8c.wav silence unknown
# clip_07d31da72.wav silence unknown
# clip_07d5d646c.wav left unknown
# clip_07db3c401.wav silence unknown
# clip_07e0e5414.wav silence unknown
# clip_07e1d7ce7.wav silence unknown
# clip_07e23544f.wav unknown no
# clip_07e4084ce.wav silence off
# clip_07f2f04dd.wav unknown silence
# clip_07f47b9b4.wav silence unknown
# clip_07fed73fa.wav silence unknown
# clip_07ffa40ac.wav off on
# clip_08023820b.wav silence unknown
# clip_080cf8d0d.wav silence unknown
# clip_0822527aa.wav unknown on
# clip_082f1d0d1.wav silence unknown
# clip_083d8ba24.wav yes unknown
# clip_083f03652.wav left unknown
# clip_0841be472.wav silence unknown
# clip_0861f4f20.wav silence unknown
# clip_0863b4421.wav unknown go
# clip_086f0b534.wav unknown silence
# clip_086ff751c.wav silence unknown
# clip_0873ddc29.wav unknown right
# clip_087c8c967.wav on off
# clip_087db6d26.wav no down
# clip_0881691e2.wav down unknown
# clip_0881c8124.wav unknown off
# clip_088304c89.wav off on
# clip_0887b5f90.wav left no
# clip_088f46d83.wav silence unknown
# clip_0892dd547.wav silence go
# clip_0895dce28.wav silence unknown
# clip_08a4f96b9.wav silence unknown
# clip_08a70e9c7.wav unknown silence
# clip_08a7959f6.wav silence unknown
# clip_08ace6abb.wav silence up
# clip_08acfe378.wav silence unknown
# clip_08ad9330b.wav silence unknown
# clip_08b26ae63.wav silence unknown
# clip_08b8e020a.wav silence unknown
# clip_08bf8b388.wav unknown silence
# clip_08c01b4c4.wav silence unknown
# clip_08c1c042f.wav silence stop
# clip_08c6a8d1e.wav right unknown
# clip_08c85ac56.wav unknown off
# clip_08c85dda6.wav down go
# clip_08cb18f84.wav silence unknown
# clip_08cb1e8ba.wav silence unknown
# clip_08cd21715.wav stop unknown
# clip_08cf70a03.wav silence unknown
# clip_08d611976.wav silence unknown
# clip_08d929f77.wav up unknown
# clip_08dd457d5.wav silence unknown
# clip_08e131919.wav silence unknown
# clip_08e7181c5.wav unknown on
# clip_08ea78c79.wav silence unknown
# clip_08ecb0694.wav unknown right
# clip_08f1f8903.wav silence go
# clip_08f9c5eaa.wav silence unknown
# clip_08fda1c94.wav left unknown
# clip_08ffaf14c.wav unknown yes
# clip_08ffcce91.wav silence unknown
# clip_090203b5f.wav silence unknown
# clip_0902313e2.wav silence unknown
# clip_0902f2d94.wav on unknown
# clip_090be8d88.wav up off
# clip_090ecd701.wav up unknown
# clip_0920eaf9c.wav unknown on
# clip_09217eabc.wav unknown silence
# clip_092212922.wav right unknown
# clip_0922268a6.wav left unknown
# clip_092696da2.wav unknown right
# clip_0934b1c55.wav unknown silence
# clip_093b37eee.wav silence unknown
# clip_093d29f52.wav unknown off
# clip_093f53408.wav silence unknown
# clip_09402c21d.wav unknown on
# clip_0945cfcf3.wav silence unknown
# clip_095765612.wav silence unknown
# clip_09576cc90.wav off on
# clip_096146e57.wav silence go
# clip_0961bfbb1.wav unknown on
# clip_0963d2940.wav silence unknown
# clip_096b277e2.wav no go
# clip_096d87ced.wav unknown silence
# clip_097086d33.wav unknown silence
# clip_09718d7eb.wav unknown silence
# clip_097b0c1ca.wav no unknown
# clip_097fcd9a0.wav unknown silence
# clip_09817153b.wav up silence
# clip_09839d44d.wav silence unknown
# clip_098792ded.wav unknown on
# clip_09920cc41.wav silence up
# clip_0992cd84c.wav unknown silence
# clip_099ad628e.wav silence unknown
# clip_09a4f0fdd.wav off up
# clip_09ad13d1f.wav unknown on
# clip_09afb91ea.wav up off
# clip_09b37c837.wav silence unknown
# clip_09b5f6d64.wav yes left
# clip_09b7404b3.wav silence unknown
# clip_09ba64dc3.wav unknown silence
# clip_09bb293cb.wav silence unknown
# clip_09bb96458.wav silence up
# clip_09be73bf1.wav unknown silence
# clip_09bff1137.wav unknown no
# clip_09c1c4518.wav off up
# clip_09c5c42a3.wav silence unknown
# clip_09c5fd8e0.wav silence unknown
# clip_09c9b76ef.wav silence unknown
# clip_09c9f1398.wav silence unknown
# clip_09ccc254a.wav silence unknown
# clip_09d44e675.wav silence unknown
# clip_09d7ebf7d.wav unknown silence
# clip_09dd610f8.wav silence unknown
# clip_09ea988de.wav unknown left
# clip_09eaa55f9.wav silence unknown
# clip_09eb3f8f6.wav right unknown
# clip_09ec4e900.wav silence unknown
# clip_09f157a0e.wav unknown silence
# clip_09f7fc0ee.wav unknown off
# clip_09fc43cb7.wav silence unknown
# clip_09fe9d99b.wav up unknown
# clip_0a02eec5e.wav left unknown
# clip_0a0e5bbcd.wav silence off
# clip_0a131ab81.wav silence unknown
# clip_0a13327dd.wav silence no
# clip_0a182caf8.wav left no
# clip_0a20785a4.wav unknown up
# clip_0a27339ee.wav silence unknown
# clip_0a2ffb4a8.wav unknown silence
# clip_0a3245320.wav silence unknown
# clip_0a3704bc8.wav unknown right
# clip_0a390298a.wav down unknown
# clip_0a3a2ea2f.wav unknown on
# clip_0a3c38e44.wav unknown down
# clip_0a3cb25a6.wav unknown no
# clip_0a3f8b8f2.wav silence unknown
# clip_0a438b74c.wav unknown silence
# clip_0a4525876.wav silence unknown
# clip_0a4f75598.wav unknown down
# clip_0a51ebc6e.wav unknown left
# clip_0a56517db.wav silence unknown
# clip_0a5aabd1b.wav unknown silence
# clip_0a6452df1.wav unknown right
# clip_0a7224c52.wav silence unknown
# clip_0a741b0c7.wav silence unknown
# clip_0a7d499e4.wav unknown on
# clip_0a884dfe5.wav unknown on
# clip_0a894b991.wav silence unknown
# clip_0a8b2d08e.wav silence unknown
# clip_0a8bf5579.wav silence unknown
# clip_0a928c340.wav unknown up
# clip_0a94e8042.wav unknown right
# clip_0a99f801a.wav silence unknown
# clip_0a9ec5f22.wav stop down
# clip_0aa2876dd.wav silence unknown
# clip_0aa82d087.wav silence up
# clip_0aa96e3e6.wav silence unknown
# clip_0abccd77d.wav unknown go
# clip_0abeeab88.wav silence unknown
# clip_0abefde5e.wav off on
# clip_0ac3b80b2.wav silence unknown
# clip_0ac6b4165.wav unknown on
# clip_0ac708dfe.wav unknown on
# clip_0ad6588af.wav silence unknown
# clip_0ae3ae6d0.wav unknown silence
# clip_0ae4c9aca.wav unknown silence
# clip_0aebd733c.wav silence unknown
# clip_0af0a5b48.wav stop unknown
# clip_0af3432e7.wav silence unknown
# clip_0af631926.wav silence unknown
# clip_0af7b47eb.wav unknown down
# clip_0afab4580.wav unknown silence
# clip_0afe9b525.wav left unknown
# clip_0aff5fd1b.wav unknown left
# clip_0b0020806.wav unknown off
# clip_0b004a947.wav no unknown
# clip_0b03173fd.wav silence unknown
# clip_0b0734c62.wav unknown down
# clip_0b076340d.wav silence unknown
# clip_0b0bc639d.wav unknown silence
# clip_0b1a69e65.wav unknown silence
# clip_0b1b105d6.wav unknown no
# clip_0b1bd8a28.wav silence unknown
# clip_0b1e9387a.wav right unknown
# clip_0b1f9017d.wav unknown right
# clip_0b2384f71.wav unknown silence
# clip_0b2862a3f.wav silence unknown
# clip_0b2897318.wav silence go
# clip_0b36dc008.wav silence unknown
# clip_0b3b4b8ee.wav silence unknown
# clip_0b3c95df2.wav unknown silence
# clip_0b3ccb974.wav silence unknown
# clip_0b4ddf677.wav silence unknown
# clip_0b4e12c3d.wav silence unknown
# clip_0b5d80f51.wav silence unknown
# clip_0b6ba9058.wav unknown go
# clip_0b6ce88a0.wav unknown go
# clip_0b712c296.wav unknown down
# clip_0b77a9e28.wav silence unknown
# clip_0b7889cda.wav silence unknown
# clip_0b7bd9527.wav silence unknown
# clip_0b80bd4ff.wav unknown silence
# clip_0b833d35c.wav unknown silence
# clip_0b862f9f6.wav silence unknown
# clip_0b87c1851.wav up off
# clip_0b8835250.wav silence unknown
# clip_0b8b9cf80.wav silence unknown
# clip_0b8c1bb78.wav silence unknown
# clip_0b96aed88.wav silence unknown
# clip_0b99e470c.wav silence unknown
# clip_0b9c44fa8.wav go no
# clip_0ba2c68a8.wav silence unknown
# clip_0ba8e3ee2.wav silence go
# clip_0ba9ee14c.wav silence unknown
# clip_0bab11f20.wav unknown silence
# clip_0baf10a96.wav unknown silence
# clip_0bb104623.wav silence unknown
# clip_0bb4231bb.wav unknown on
# clip_0bbc0035d.wav silence unknown
# clip_0bbcd36fa.wav up off
# clip_0bbeb6df3.wav unknown no
# clip_0bc81a39f.wav unknown down
# clip_0bcba5c3d.wav unknown on
# clip_0bd10cdc7.wav unknown no
# clip_0bd491d6f.wav silence unknown
# clip_0bf068834.wav silence unknown
# clip_0bf5a191d.wav off unknown
# clip_0bf781a61.wav unknown silence
# clip_0bf822b61.wav silence unknown
# clip_0bfb93378.wav unknown go
# clip_0c03ce5a4.wav silence unknown
# clip_0c0571265.wav silence unknown
# clip_0c0b8c8d9.wav unknown silence
# clip_0c0c53f42.wav unknown silence
# clip_0c1a5756b.wav unknown down
# clip_0c223eda7.wav silence unknown
# clip_0c2974dd7.wav silence unknown
# clip_0c29ff3ef.wav silence unknown
# clip_0c2c37264.wav unknown down
# clip_0c30d259b.wav left unknown
# clip_0c32e3c63.wav unknown left
# clip_0c39ff544.wav unknown no
# clip_0c434cca1.wav silence unknown
# clip_0c4b89627.wav silence unknown
# clip_0c5094386.wav unknown left
# clip_0c590426a.wav down no
# clip_0c5a049a1.wav silence unknown
# clip_0c5a79c95.wav right unknown
# clip_0c5ad4aff.wav silence unknown
# clip_0c5cc392e.wav silence unknown
# clip_0c6170a6c.wav unknown go
# clip_0c69f128d.wav left no
# clip_0c6d11fda.wav no go
# clip_0c7138fb5.wav silence unknown
# clip_0c7408a8e.wav unknown silence
# clip_0c7651316.wav silence unknown
# clip_0c78cbd09.wav silence unknown
# clip_0c7a85937.wav unknown no
# clip_0c80f6b2e.wav silence unknown
# clip_0c83253c9.wav unknown no
# clip_0c8c12e6a.wav unknown up
# clip_0c8fd4acb.wav silence unknown
# clip_0c972953c.wav silence unknown
# clip_0c9d8ee29.wav off unknown
# clip_0c9e6dfb7.wav silence unknown
# clip_0ca5bb936.wav unknown silence
# clip_0ca7ab836.wav unknown go
# clip_0cb3d2455.wav unknown no
# clip_0cb88cf0f.wav silence unknown
# clip_0cba8f1c0.wav silence unknown
# clip_0cc8de86d.wav silence unknown
# clip_0cca4c28d.wav silence unknown
# clip_0ccab0826.wav stop down
# clip_0ccab64a0.wav silence go
# clip_0cd379ef0.wav unknown silence
# clip_0cdbbfa25.wav unknown on
# clip_0cdfb0459.wav unknown down
# clip_0cea81cc1.wav silence unknown
# clip_0cea9e6fb.wav unknown go
# clip_0cf8aed33.wav silence unknown
# clip_0d00aa1ce.wav unknown off
# clip_0d02a24e9.wav unknown no
# clip_0d10b6342.wav unknown stop
# clip_0d11a3f80.wav unknown left
# clip_0d14b8b6e.wav unknown left
# clip_0d1e9b7cc.wav unknown off
# clip_0d1f4e6b0.wav silence unknown
# clip_0d21386c8.wav on down
# clip_0d239d231.wav silence unknown
# clip_0d25e816f.wav silence unknown
# clip_0d29a7679.wav unknown right
# clip_0d2b83f02.wav silence unknown
# clip_0d316bb2d.wav silence unknown
# clip_0d3745644.wav silence unknown
# clip_0d3977450.wav off on
# clip_0d3a6e293.wav up unknown
# clip_0d3c951c7.wav silence unknown
# clip_0d3d2f07a.wav silence unknown
# clip_0d4f46afb.wav unknown off
# clip_0d5097686.wav unknown up
# clip_0d519930c.wav unknown left
# clip_0d58e5656.wav unknown silence
# clip_0d5a001b1.wav silence unknown
# clip_0d5aff80b.wav silence unknown
# clip_0d5b3e002.wav silence unknown
# clip_0d5bc3f04.wav unknown silence
# clip_0d5c02cf3.wav silence unknown
# clip_0d60516dd.wav silence unknown
# clip_0d6318bbe.wav unknown off
# clip_0d66fcca5.wav no unknown
# clip_0d6b1039e.wav silence unknown
# clip_0d6e0ccaa.wav silence go
# clip_0d7122c3c.wav unknown silence
# clip_0d780d95b.wav silence off
# clip_0d7876d7a.wav silence unknown
# clip_0d792a769.wav silence unknown
# clip_0eaf86051.wav down unknown
# clip_0ec02bbfe.wav unknown on
# clip_0ec593717.wav silence right
# clip_0ec6e0195.wav silence unknown
# clip_0ec7160ae.wav unknown go
# clip_0ece82456.wav unknown silence
# clip_0ece9ad48.wav unknown no
# clip_0ed2803a5.wav unknown right
# clip_0edb0f6fb.wav unknown silence
# clip_0edbdd326.wav go unknown
# clip_0ee29261e.wav off unknown
# clip_0ee307039.wav silence unknown
# clip_0ee625844.wav unknown yes
# clip_0eeccae90.wav unknown no
# clip_0ef17a8cc.wav unknown silence
# clip_0ef19eba8.wav unknown left
# clip_0ef807ed8.wav silence unknown
# clip_0ef884f3a.wav silence right
# clip_0f01e56f7.wav unknown go
# clip_0f02c0ae3.wav unknown go
# clip_0f02d8764.wav silence unknown
# clip_0f04d1608.wav silence go
# clip_0f077bdc5.wav left unknown
# clip_0f0a36969.wav unknown down
# clip_0f113bb9e.wav on unknown
# clip_0f1951af6.wav unknown on
# clip_0f1cf10d8.wav left unknown
# clip_0f2477e45.wav silence unknown
# clip_0f29c42f5.wav up go
# clip_0f30abd6e.wav silence go
# clip_0f35e5df9.wav silence unknown
# clip_0f36df38a.wav unknown silence
# clip_0f3823b64.wav unknown silence
# clip_0f3e061fa.wav left unknown
# clip_0f41c07ad.wav unknown silence
# clip_0f426ae3e.wav unknown silence
# clip_0f432d267.wav no go
# clip_0f436a0d4.wav unknown silence
# clip_0f455cbc6.wav silence unknown
# clip_0f4812be9.wav left off
# clip_0f4b18c73.wav unknown off
# clip_0f4d9ef7e.wav unknown right
# clip_0f537c047.wav no unknown
# clip_0f545fd00.wav silence unknown
# clip_0f57e5505.wav silence unknown
# clip_0f5855222.wav no unknown
# clip_0f6274983.wav silence unknown
# clip_0f62dab67.wav unknown left
# clip_0f6df4bd7.wav silence unknown
# clip_0f6e4b54b.wav unknown right
# clip_0f6f4904a.wav unknown go
# clip_0f702e5d4.wav unknown silence
# clip_0f792f7be.wav silence unknown
# clip_0f7ddfb00.wav go down
# clip_0f7fd595f.wav down go
# clip_0f80c08cb.wav silence unknown
# clip_0f8bfd8fa.wav unknown silence
# clip_0f9658f01.wav unknown silence
# clip_0f9a87fa3.wav silence unknown
# clip_0f9d9eb00.wav go down
# clip_0f9e53cd4.wav unknown go
# clip_0fa48843e.wav unknown up
# clip_0fb0f73ad.wav unknown yes
# clip_0fb1bbd49.wav silence unknown
# clip_0fb374fe4.wav unknown down
# clip_0fb6a1122.wav unknown silence
# clip_0fb6bed65.wav unknown right
# clip_0fb709b2b.wav silence unknown
# clip_0fc15cec6.wav silence unknown
# clip_0fc29bb7a.wav unknown silence
# clip_0fc443bf5.wav silence unknown
# clip_0fc68c234.wav unknown silence
# clip_0fd0599e1.wav silence unknown
# clip_0fdce9c54.wav silence unknown
# clip_0fdf7d316.wav silence unknown
# clip_0fe00a499.wav down unknown
# clip_0fe139f1a.wav unknown silence
# clip_0fe2fa06f.wav unknown right
# clip_0fe4c3230.wav go no
# clip_0fe647ce7.wav unknown on
# clip_12ce1c12d.wav silence unknown
# clip_12ce857bb.wav silence off
# clip_12cfe8751.wav silence unknown
# clip_12d789d1d.wav silence unknown
# clip_12da41b41.wav stop go
# clip_12dc1ae8f.wav unknown off
# clip_12e0e21fa.wav silence unknown
# clip_12e1dfc33.wav silence unknown
# clip_12e744371.wav silence unknown
# clip_12e786f07.wav silence unknown
# clip_12e7d1fc4.wav unknown silence
# clip_12e94e1d8.wav unknown silence
# clip_12fc62ab8.wav unknown stop
# clip_130728c6d.wav left right
# clip_130abe9f4.wav unknown silence
# clip_130b529cf.wav silence unknown
# clip_130c4489f.wav left up
# clip_13102e180.wav unknown right
# clip_1324b68fb.wav silence unknown
# clip_1326df240.wav unknown silence
# clip_13298837d.wav unknown up
# clip_132c7aaea.wav silence unknown
# clip_133745d30.wav unknown up
# clip_133e47e81.wav off up
# clip_13450d0fb.wav silence up
# clip_134748e6f.wav silence unknown
# clip_134ca81b1.wav unknown on
# clip_13598c9a2.wav unknown right
# clip_1371cd208.wav silence unknown
# clip_137547a61.wav silence unknown
# clip_13790b293.wav up off
# clip_137d8b5b2.wav silence unknown
# clip_137e0449e.wav silence unknown
# clip_137f8a8b1.wav unknown go
# clip_137ff4093.wav off unknown
# clip_1382e2e1a.wav silence go
# clip_138447b5e.wav unknown silence
# clip_13849fab2.wav unknown silence
# clip_1390c8f2e.wav silence unknown
# clip_139130577.wav silence unknown
# clip_139a65098.wav unknown silence
# clip_139cf9b16.wav unknown silence
# clip_139d6f238.wav unknown on
# clip_13a24ffa3.wav silence unknown
# clip_13a5b9336.wav silence unknown
# clip_13a656579.wav silence unknown
# clip_13a853b9b.wav silence unknown
# clip_13a920d42.wav unknown on
# clip_13b241083.wav unknown go
# clip_13b3ee72d.wav silence unknown
# clip_13b4f211b.wav unknown yes
# clip_13b7c381c.wav unknown silence
# clip_13bd20421.wav silence unknown
# clip_13c1445be.wav silence unknown
# clip_13cd1a6e7.wav silence unknown
# clip_13d35cf31.wav silence unknown
# clip_13da22229.wav unknown on
# clip_13dd1d0ff.wav down unknown
# clip_13e662df5.wav silence unknown
# clip_13e76c8da.wav unknown no
# clip_13eb1b178.wav down unknown
# clip_13ec87909.wav silence unknown
# clip_13ece1a11.wav silence unknown
# clip_13f2fa053.wav left unknown
# clip_13f827458.wav unknown no
# clip_13fae57f8.wav silence unknown
# clip_13fcb90a4.wav silence unknown
# clip_13fcf97ea.wav unknown silence
# clip_140e46f37.wav silence unknown
# clip_140efafe4.wav left unknown
# clip_1412e110e.wav unknown left
# clip_14146fdad.wav no go
# clip_141709eae.wav unknown silence
# clip_1424555a4.wav silence unknown
# clip_1429c2c09.wav unknown right
# clip_142ba9dbd.wav unknown silence
# clip_142e7ff1b.wav silence unknown
# clip_14314e7dc.wav silence unknown
# clip_143885381.wav unknown stop
# clip_143ac52e2.wav silence unknown
# clip_143af5312.wav silence unknown
# clip_14406003c.wav silence unknown
# clip_1440f3b94.wav silence unknown
# clip_1445eb777.wav up off
# clip_144918d75.wav silence unknown
# clip_144c909cf.wav unknown silence
# clip_144d071be.wav silence unknown
# clip_14534d716.wav unknown silence
# clip_1454d7a98.wav silence unknown
# clip_145b3439a.wav unknown down
# clip_145bfd4a2.wav silence unknown
# clip_14602f540.wav left yes
# clip_146656918.wav unknown go
# clip_146918e73.wav unknown no
# clip_147120d22.wav stop unknown
# clip_1472c1ea1.wav silence unknown
# clip_1477d9696.wav silence unknown
# clip_147bb76b1.wav silence unknown
# clip_148245b04.wav unknown silence
# clip_1485d0023.wav silence unknown
# clip_148858938.wav unknown no
# clip_1489fdb79.wav unknown no
# clip_14971376c.wav unknown on
# clip_14a48e524.wav up off
# clip_14a5e6921.wav left right
# clip_14a79e4d4.wav unknown up
# clip_14aa6ff03.wav silence unknown
# clip_14ad7fdf1.wav unknown left
# clip_14b400b36.wav silence unknown
# clip_14b6ca016.wav silence unknown
# clip_14b8e390b.wav silence unknown
# clip_14b95c5fc.wav unknown silence
# clip_14b9f345c.wav stop unknown
# clip_14bde9946.wav unknown up
# clip_14bf31edc.wav silence unknown
# clip_14c10f3a3.wav unknown on
# clip_14caa80aa.wav silence unknown
# clip_14cce9dfb.wav silence unknown
# clip_14d4f8751.wav silence unknown
# clip_14df12ec5.wav unknown off
# clip_14e8df575.wav silence unknown
# clip_14ebd8a6c.wav silence unknown
# clip_14ec9dd06.wav silence unknown
# clip_14ed2e4f7.wav silence no
# clip_14ed83c31.wav silence unknown
# clip_14f67acb7.wav unknown silence
# clip_14f743723.wav unknown silence
# clip_14ffbd45c.wav silence unknown
# clip_150223f3b.wav silence unknown
# clip_1505a2c5d.wav unknown off
# clip_15066cd26.wav silence unknown
# clip_150b0294c.wav unknown no
# clip_151372c4f.wav up off
# clip_151603dc0.wav up unknown
# clip_151ab35c4.wav left unknown
# clip_151b20d6c.wav unknown up
# clip_151c99837.wav silence unknown
# clip_151cf07bc.wav unknown right
# clip_15228e01e.wav silence unknown
# clip_1525e9c9c.wav unknown silence
# clip_152a2b9ed.wav unknown left
# clip_152ad1bf3.wav unknown no
# clip_152be8a46.wav on unknown
# clip_15305afaf.wav unknown silence
# clip_15331a06c.wav unknown silence
# clip_1533cd3c6.wav silence up
# clip_1537be382.wav silence unknown
# clip_153f13ca3.wav silence unknown
# clip_1541de8ee.wav unknown on
# clip_154f0a9a7.wav left unknown
# clip_155ac855b.wav silence unknown
# clip_155eb3784.wav up off
# clip_155f60793.wav silence unknown
# clip_156010e28.wav no go
# clip_15661164c.wav unknown down
# clip_1570da9df.wav unknown go
# clip_15757e965.wav left stop
# clip_157581a20.wav up unknown
# clip_157871a3b.wav no yes
# clip_157d3811c.wav silence unknown
# clip_15801866b.wav yes unknown
# clip_158aa5a63.wav silence unknown
# clip_159a37672.wav no right
# clip_159f3a4c6.wav on go
# clip_15a0a6041.wav silence unknown
# clip_15a35e5cb.wav unknown go
# clip_15a3ca972.wav unknown on
# clip_15a3f0d60.wav no unknown
# clip_15a792051.wav unknown stop
# clip_15bdd90af.wav silence unknown
# clip_15c657437.wav unknown down
# clip_15ca004c9.wav silence unknown
# clip_15ca2fb68.wav unknown no
# clip_15ca955ab.wav unknown left
# clip_15d081a9d.wav silence unknown
# clip_15db2a689.wav unknown on
# clip_15e2979c0.wav silence unknown
# clip_15e996bb7.wav silence unknown
# clip_15eae592f.wav unknown silence
# clip_15ec45fa1.wav silence unknown
# clip_15ec702b5.wav unknown right
# clip_15f092c77.wav silence down
# clip_15f6c6911.wav on unknown
# clip_15f9567c4.wav unknown silence
# clip_15f9d886f.wav unknown off
# clip_1605822c3.wav silence unknown
# clip_160973785.wav left no
# clip_160d3ee69.wav silence unknown
# clip_1611f7968.wav unknown on
# clip_161283a3e.wav silence unknown
# clip_161f54db8.wav unknown silence
# clip_163b7b264.wav silence unknown
# clip_16430ae53.wav unknown on
# clip_164b7d62a.wav silence unknown
# clip_164f1d493.wav unknown silence
# clip_1650ed3cd.wav silence unknown
# clip_165484d65.wav unknown on
# clip_1657f488f.wav silence unknown
# clip_165b633e0.wav silence unknown
# clip_165dc2bdd.wav off up
# clip_1662cbf56.wav silence yes
# clip_16693cfa3.wav unknown no
# clip_166e7941b.wav unknown silence
# clip_166f2a6fe.wav unknown go
# clip_16728db6c.wav down on
# clip_16795ea97.wav silence up
# clip_167bce5ce.wav unknown silence
# clip_167de7570.wav silence unknown
# clip_168302281.wav up unknown
# clip_16892bbaa.wav silence unknown
# clip_168974de0.wav silence unknown
# clip_168975fee.wav unknown silence
# clip_168cd4cb6.wav unknown up
# clip_168e4321f.wav unknown no
# clip_168f46b9a.wav silence unknown
# clip_1690429e1.wav unknown silence
# clip_1694ab520.wav unknown silence
# clip_1696b0d72.wav unknown silence
# clip_169709770.wav unknown down
# clip_169871f0c.wav silence unknown
# clip_16a7b62ca.wav unknown silence
# clip_16b4cca47.wav silence unknown
# clip_16b62e42c.wav silence unknown
# clip_16bf8059c.wav silence unknown
# clip_16c483209.wav unknown silence
# clip_16c6199e3.wav silence unknown
# clip_16c78d21d.wav silence unknown
# clip_16caed099.wav silence up
# clip_16cf8d3b0.wav silence unknown
# clip_16d9b74c6.wav silence unknown
# clip_16e3e2377.wav silence unknown
# clip_16e5acd01.wav unknown go
# clip_16e71f79a.wav unknown silence
# clip_16fb36a69.wav silence unknown
# clip_170a5a0c0.wav unknown down
# clip_170d33468.wav unknown go
# clip_1711c71d5.wav on go
# clip_17124947c.wav right unknown
# clip_1719d985a.wav unknown no
# clip_1726fe2e3.wav silence unknown
# clip_172779fd7.wav silence unknown
# clip_172d91b4f.wav silence unknown
# clip_1741728ec.wav silence unknown
# clip_174dc969b.wav silence unknown
# clip_174ed4847.wav silence right
# clip_1751987bd.wav unknown down
# clip_175625fe6.wav unknown on
# clip_175d3d42d.wav no down
# clip_175d9db9d.wav silence unknown
# clip_175e92e94.wav silence unknown
# clip_175ee003c.wav silence right
# clip_1767083b7.wav silence unknown
# clip_176beaab9.wav silence unknown
# clip_178006f4f.wav silence unknown
# clip_f9dbe8548.wav silence unknown
# clip_f9e958810.wav unknown silence
# clip_f9eba6003.wav unknown on
# clip_f9ec8577b.wav silence unknown
# clip_f9edc7063.wav unknown silence
# clip_f9f13575e.wav no go
# clip_f9f6eb123.wav unknown go
# clip_f9f702703.wav silence unknown
# clip_f9f8c9aaa.wav up unknown
# clip_f9fba20e0.wav left unknown
# clip_f9fd95dee.wav unknown silence
# clip_f9ff32b94.wav unknown right
# clip_fa00f6f80.wav unknown silence
# clip_fa0488422.wav silence unknown
# clip_fa0c97042.wav silence go
# clip_fa0f8e7c3.wav unknown silence
# clip_fa100d092.wav silence go
# clip_fa10b2b26.wav stop silence
# clip_fa17ece3e.wav unknown down
# clip_fa1d453b7.wav silence unknown
# clip_fa20189de.wav off up
# clip_fa20c8b4b.wav stop go
# clip_fa25d11c3.wav silence unknown
# clip_fa2f7d663.wav unknown right
# clip_fa334fa80.wav silence unknown
# clip_fa356984b.wav unknown right
# clip_fa3624fab.wav unknown off
# clip_fa3973cdc.wav unknown on
# clip_fa4ea9324.wav up silence
# clip_fa547fda1.wav silence unknown
# clip_fa5bd392d.wav unknown silence
# clip_fa5ff41a0.wav silence unknown
# clip_fa62e2e8b.wav unknown go
# clip_fa64a2411.wav unknown silence
# clip_fa65576b0.wav silence unknown
# clip_fa671e250.wav unknown silence
# clip_fa68b4eb8.wav silence unknown
# clip_fa7709058.wav silence unknown
# clip_fa799ee01.wav unknown silence
# clip_fa79ddb96.wav silence unknown
# clip_fa80a6236.wav unknown silence
# clip_fa8422b4a.wav silence unknown
# clip_fa883c3e3.wav unknown on
# clip_fa93f4139.wav silence unknown
# clip_fa9572136.wav silence unknown
# clip_fa9a02396.wav silence unknown
# clip_faa093a28.wav unknown down
# clip_faa2b94ef.wav silence unknown
# clip_faa7bf00e.wav unknown no
# clip_faa8d3685.wav unknown on
# clip_faa9b8b8f.wav silence unknown
# clip_faadaa35e.wav unknown on
# clip_fab21b987.wav silence unknown
# clip_fab429f77.wav silence unknown
# clip_fab9c62d5.wav silence unknown
# clip_fabbea16e.wav unknown silence
# clip_fabe2b2d6.wav silence unknown
# clip_fac6978bb.wav unknown silence
# clip_fac88cec6.wav up off
# clip_fac8ef334.wav unknown silence
# clip_facd4f6aa.wav go no
# clip_fadfde492.wav unknown silence
# clip_fae41256b.wav off up
# clip_fae7334aa.wav silence unknown
# clip_fae81861e.wav unknown silence
# clip_faf1ad3c8.wav go stop
# clip_faf1f98b4.wav unknown on
# clip_faf313839.wav unknown silence
# clip_fafce100a.wav silence unknown
# clip_fafe9b84b.wav silence unknown
# clip_fafeb5384.wav unknown on
# clip_fb037e76c.wav unknown silence
# clip_fb0777ecc.wav silence unknown
# clip_fb0a46c91.wav silence unknown
# clip_fb0cf4ffb.wav silence unknown
# clip_fb1488e62.wav down unknown
# clip_fb1c4f6e1.wav silence unknown
# clip_fb27f2249.wav silence unknown
# clip_fb28ad43c.wav up go
# clip_fb2a604c0.wav silence unknown
# clip_fb2c807e7.wav silence unknown
# clip_fb306e8b0.wav silence unknown
# clip_fb3882d33.wav unknown silence
# clip_fb3942bfb.wav go down
# clip_fb3f36788.wav unknown silence
# clip_fb42f5e4d.wav unknown right
# clip_fb49cfbe5.wav unknown silence
# clip_fb4b955d8.wav no down
# clip_fb5290bf8.wav unknown go
# clip_fb52e1590.wav silence unknown
# clip_fb53239a9.wav silence unknown
# clip_fb57f449a.wav unknown on
# clip_fb5c1736a.wav up stop
# clip_fb5dbbf59.wav silence unknown
# clip_fb60a741e.wav silence unknown
# clip_fb65bb481.wav silence unknown
# clip_fb667f509.wav no unknown
# clip_fb6edeb1b.wav silence unknown
# clip_fb706011b.wav unknown up
# clip_fb74859e7.wav silence unknown
# clip_fb7be7046.wav no go
# clip_fb7ec8899.wav stop unknown
# clip_fb7fb0dba.wav go on
# clip_fb892b7f9.wav unknown on
# clip_fb9156562.wav right unknown
# clip_fb98a890a.wav on unknown
# clip_fb9a8443c.wav silence unknown
# clip_fba29474c.wav unknown left
# clip_fba4626e0.wav unknown silence
# clip_fba901fc8.wav up off
# clip_fbac325ca.wav unknown no
# clip_fbafc6069.wav unknown silence
# clip_fbb3ad94f.wav silence unknown
# clip_fbb73b1e7.wav unknown silence
# clip_fbbfa480c.wav down unknown
# clip_fbc07b85c.wav silence unknown
# clip_fbc0b367b.wav silence unknown
# clip_fbc135b49.wav silence unknown
# clip_fbc3b64ef.wav off up
# clip_fbc63a040.wav silence unknown
# clip_fbc6e8e0b.wav unknown silence
# clip_fbc96dab1.wav silence unknown
# clip_fbccf198b.wav silence unknown
# clip_fbce5b3ce.wav unknown no
# clip_fbcebd597.wav go on
# clip_fbe2d3e01.wav unknown silence
# clip_fbec9bccb.wav silence unknown
# clip_fbf4343f4.wav silence unknown
# clip_fbf4de30a.wav unknown yes
# clip_fbfc43c32.wav unknown left
# clip_fbfdb37d6.wav silence go
# clip_fbff75b3f.wav silence unknown
# clip_fc1050144.wav left unknown
# clip_fc1059c5e.wav silence unknown
# clip_fc120fc62.wav unknown silence
# clip_fc1827f4f.wav unknown silence
# clip_fc1863591.wav silence unknown
# clip_fc1dab0b5.wav unknown on
# clip_fc1dc4104.wav go stop
# clip_fc1de2fc7.wav unknown right
# clip_fc20f5d26.wav silence unknown
# clip_fc25508f8.wav no unknown
# clip_fc2cd75f7.wav silence unknown
# clip_fc3100186.wav silence unknown
# clip_fc37b7e9b.wav no unknown
# clip_fc3f32acf.wav silence unknown
# clip_fc40d43b2.wav silence unknown
# clip_fc586ee4a.wav silence unknown
# clip_fc6263a7c.wav silence unknown
# clip_fc665aa2c.wav off up
# clip_fc70ff20b.wav silence right
# clip_fc7bd1c7c.wav unknown left
# clip_fc80a1c65.wav silence unknown
# clip_fc8833fb1.wav silence unknown
# clip_fc9613ddf.wav unknown silence
# clip_fc96ee15c.wav unknown on
# clip_fc9e1f46d.wav silence unknown
# clip_fca1c1027.wav silence unknown
# clip_fca27eea1.wav unknown silence
# clip_fca820b8c.wav up off
# clip_fcace5545.wav unknown silence
# clip_fcadfd154.wav silence unknown
# clip_fcb4dfc2c.wav silence unknown
# clip_fcb68dea4.wav unknown stop
# clip_fcb919b13.wav silence unknown
# clip_fcc373fed.wav unknown down
# clip_fcc3ecbf2.wav unknown on
# clip_fccc4c11b.wav unknown no
# clip_fcd429eb4.wav silence unknown
# clip_fcda9b438.wav up unknown
# clip_fcdd12e56.wav silence unknown
# clip_fce2da492.wav go no
# clip_fce952259.wav no unknown
# clip_fcefd9401.wav silence unknown
# clip_fcf0adcbf.wav unknown left
# clip_fcf1e748c.wav unknown no
# clip_fcf616097.wav right unknown
# clip_fcfa78827.wav unknown silence
# clip_fd000cea3.wav silence down
# clip_fd009c75a.wav silence unknown
# clip_fd00edaef.wav silence unknown
# clip_fd1f24616.wav unknown down
# clip_fd1fa5b0a.wav silence unknown
# clip_fd27cb018.wav silence unknown
# clip_fd30dffbf.wav silence unknown
# clip_fd3f79abd.wav silence unknown
# clip_fd46351dd.wav silence unknown
# clip_fd48525f1.wav unknown silence
# clip_fd5e29a4c.wav silence unknown
# clip_fd5fd0295.wav silence unknown
# clip_fd6e4e4bf.wav unknown stop
# clip_fd6e5fa06.wav yes no
# clip_fd6f4e065.wav stop silence
# clip_fd70f41be.wav silence unknown
# clip_fd7240e70.wav unknown silence
# clip_fd7958f77.wav down unknown
# clip_fd82b9cc3.wav unknown go
# clip_fd869a825.wav silence unknown
# clip_fd8a3b65c.wav silence unknown
# clip_fd90bf5ee.wav left unknown
# clip_fd93634b4.wav unknown silence
# clip_fd96041c7.wav silence unknown
# clip_fd968d1d6.wav silence unknown
# clip_fda337724.wav silence unknown
# clip_fda40a6ba.wav silence unknown
# clip_fda577fa0.wav silence unknown
# clip_fda9e9a9e.wav silence up
# clip_fda9fa0d2.wav unknown left
# clip_fdac90b5b.wav up on
# clip_fdacba7a1.wav go down
# clip_fdaefbf60.wav on unknown
# clip_fdb88ed4b.wav silence unknown
# clip_fdb91b554.wav silence unknown
# clip_fdba015d2.wav silence unknown
# clip_fdbe3a1c7.wav silence up
# clip_fdc8cb57d.wav silence unknown
# clip_fdcbdb12d.wav silence unknown
# clip_fdcc72a8c.wav silence go
# clip_fdea9142b.wav silence go
# clip_fdf2b645f.wav unknown silence
# clip_fdf74e0e1.wav unknown on
# clip_fdf8bec0b.wav unknown silence
# clip_fdfa44f6e.wav unknown on
# clip_fdfbec7fd.wav silence right
# clip_fdff32922.wav unknown on
# clip_fe0c85045.wav left no
# clip_fe0ca9f9e.wav silence unknown
# clip_fe0cf3f16.wav silence unknown
# clip_fe0d8f1c5.wav left no
# clip_fe0e00ea3.wav unknown on
# clip_fe11f156d.wav no right
# clip_fe16e1297.wav silence unknown
# clip_fe1a1c30f.wav silence unknown
# clip_fe226a1b0.wav unknown down
# clip_fe24295c4.wav silence unknown
# clip_fe28b90c6.wav silence unknown
# clip_fe341aff5.wav unknown silence
# clip_fe352ac47.wav silence unknown
# clip_fe3902f24.wav silence unknown
# clip_fe39d8592.wav on unknown
# clip_fe3a37c20.wav unknown down
# clip_fe3de4a0b.wav silence unknown
# clip_fe3f3029f.wav unknown down
# clip_fe4ffc6b2.wav unknown off
# clip_fe545f932.wav unknown no
# clip_fe55bf93b.wav silence unknown
# clip_fe5b7d138.wav unknown up
# clip_fe5d32f85.wav silence unknown
# clip_fe5e38fbb.wav silence unknown
# clip_fe6514db2.wav down no
# clip_fe6877c54.wav unknown right
# clip_fe6ad924d.wav silence unknown
# clip_fe6e4de3b.wav unknown silence
# clip_fe6f990cd.wav silence unknown
# clip_fe72c9cc4.wav silence unknown
# clip_fe74023c6.wav unknown yes
# clip_fe7cb6145.wav silence unknown
# clip_fe8253850.wav unknown on
# clip_fe8280531.wav silence unknown
# clip_fe8a45555.wav silence unknown
# clip_fe8c43606.wav silence unknown
# clip_fe8ce6419.wav silence unknown
# clip_fe932854d.wav on unknown
# clip_fe93adfac.wav no go
# clip_fe9b406ea.wav unknown on
# clip_fea4acc43.wav yes unknown
# clip_feb082793.wav unknown no
# clip_feb5b6a4a.wav left unknown
# clip_feb7b72e3.wav silence unknown
# clip_fec2cd09a.wav unknown go
# clip_fec8ebfb0.wav silence unknown
# clip_feccef0d9.wav unknown silence
# clip_fed22fcd9.wav yes no
# clip_fed63a01e.wav silence unknown
# clip_fedb26d73.wav silence unknown
# clip_fedbb3919.wav silence unknown
# clip_fede200cf.wav silence unknown
# clip_fee67e506.wav unknown silence
# clip_fee9f9d47.wav silence up
# clip_feea1276c.wav silence unknown
# clip_feea1fc9d.wav unknown down
# clip_feeb3444a.wav unknown silence
# clip_feeb71d55.wav silence unknown
# clip_feebb829e.wav silence unknown
# clip_feed92ddf.wav silence unknown
# clip_fef0c201d.wav unknown silence
# clip_fef84c47c.wav silence unknown
# clip_fef8c0495.wav off left
# clip_feff677b0.wav unknown right
# clip_ff0b5fada.wav silence up
# clip_ff16a41c5.wav unknown silence
# clip_ff17a39aa.wav unknown right
# clip_ff1a9f03d.wav silence unknown
# clip_ff1b1158a.wav silence unknown
# clip_ff1db46bc.wav silence unknown
# clip_ff259fa6e.wav left up
# clip_ff2bf280d.wav silence unknown
# clip_ff3183f0f.wav unknown right
# clip_ff32d0763.wav on up
# clip_ff3560d1b.wav silence unknown
# clip_ff39de65a.wav silence unknown
# clip_ff3b117fa.wav unknown off
# clip_ff3b3424a.wav silence unknown
# clip_ff3b5c5fe.wav silence unknown
# clip_ff3c829d5.wav silence unknown
# clip_ff3eb9c5f.wav unknown silence
# clip_ff3eccdb8.wav silence unknown
# clip_ff446ab10.wav unknown on
# clip_ff45eb15f.wav silence unknown
# clip_ff4c9f077.wav silence unknown
# clip_ff55a2d7a.wav unknown silence
# clip_ff575ef48.wav unknown no
# clip_ff57ba033.wav silence unknown
# clip_ff6b95ddf.wav silence unknown
# clip_ff6bd189e.wav unknown silence
# clip_ff715c3c9.wav unknown off
# clip_ff71c555b.wav silence unknown
# clip_ff74ab2d2.wav no down
# clip_ff7d18294.wav up off
# clip_ff7da68f0.wav unknown silence
# clip_ff834ec9c.wav off up
# clip_ff8a61c7d.wav silence unknown
# clip_ff8b4da47.wav unknown silence
# clip_ff9b1bcd4.wav unknown no
# clip_ff9f2b157.wav silence unknown
# clip_ffa1b8adb.wav unknown on
# clip_ffa38ed11.wav unknown silence
# clip_ffab62234.wav stop unknown
# clip_ffab7146f.wav unknown on
# clip_ffb0cc25d.wav unknown silence
# clip_ffb1e3c5f.wav unknown on
# clip_ffb201865.wav silence no
# clip_ffb739879.wav unknown left
# clip_ffba0f53c.wav silence stop
# clip_ffc363b66.wav silence unknown
# clip_ffc715e2e.wav silence up
# clip_ffc738b96.wav unknown silence
# clip_ffd4389af.wav unknown silence
# clip_ffdfef23b.wav unknown right
# clip_fff2d4e10.wav silence unknown
# clip_fff392ff8.wav silence unknown
# clip_fff598c64.wav silence unknown
# clip_fff95115c.wav silence unknown
# clip_fffb489d7.wav no left
# clip_fffd5cf54.wav unknown silence
# clip_ffff98589.wav unknown silence
# 14715

# %%
from collections import Counter

p = pd.read_csv('../output/preds/mean_[v+r+i+x].csv', index_col='fname').values
p = np.argmax(p, axis=1)
p = [ID2NAME[i] for i in p]

best = pd.read_csv('../output/best.csv').label.values

count_p = Counter(list(p))
count_best = Counter(list(best))

# print(count_p)

# print(count_best)
# print(list(count_best.keys()))
# print(np.array(list(count_best.values())) - np.array(list(count_p1.values())))

keys = list(count_best.keys())
for k in keys:
    print('{}: {}'.format(k, count_best[k] - count_p[k]))
    
print(sum(p != best))
# Out:
# silence: -573
# stop: 65
# go: 506
# no: 396
# yes: 71
# up: 325
# down: 84
# left: 183
# on: 402
# unknown: -1880
# off: 204
# right: 217
# 9082

# %%
silence: 1797
stop: -70
go: 385
no: 119
yes: 6
up: -8
down: 272
left: -277
on: 312
unknown: -2786
off: 29
right: 221

# %%
from predict import make_submission

p1 = pd.read_csv('../output/preds/xcep_my_my_n.csv', index_col='fname').values
p2 = pd.read_csv('../output/preds/inc_139_my_my_n.csv', index_col='fname').values
p = np.argmax(0.5*p1 + 0.5*p2, axis=1)

make_submission(pd.read_csv('../output/preds/inc_139_my_my_n.csv').fname.values, p, '[i+x]_my_my_n')

# %%
preds = pd.read_csv('../output/preds/inc_139_my_n.csv', index_col='fname').values
pred_classes = np.argmax(preds, axis=1)

cond = np.logical_and(pred_classes == 10, preds[:,11] > 0.35)
preds[np.where(cond)[0], 11] = 1.0

pred_classes = np.argmax(preds, axis=1)
p = [ID2NAME[i] for i in pred_classes]

best = pd.read_csv('../output/best.csv').label.values
print(sum(p != best))
# Out:
# 9479

# %% [markdown]
# new -> best: 12936
# new -> old: 13912
# old -> best: 10483
#
# best - new:
# unknown down stop go  left  on right  no silence up  off   yes
# -639    132 -144  468 -964  543 -124  290  342   348 -230  -22

# %%
list(count_best)
# Out:
# ['yes',
#  'off',
#  'on',
#  'stop',
#  'go',
#  'right',
#  'left',
#  'down',
#  'unknown',
#  'silence',
#  'no',
#  'up']

# %%
print(diff_preds2('../output/preds/r50_f.csv', '../output/subm_majorty.csv'))
print(diff_preds('../output/resnet50_224.csv', '../output/subm_majorty.csv'))
print(diff_preds2('../output/preds/r50_f.csv', '../output/resnet50_224.csv', ))

# %%
print(diff_preds('../output/r50_199_f.csv', '../output/subm_majorty.csv'))
print(diff_preds('../output/r50_199_f.csv', '../output/subm_majorty.csv'))
# Out:
# 16653
# 16653

# %%
print(diff_preds2('../output/preds/r50_199_f.csv', '../output/subm_majorty.csv'))
print(diff_preds('../output/resnet50_fixed.csv', '../output/subm_majorty.csv'))
print(diff_preds2('../output/preds/r50_199_f.csv', '../output/resnet50_fixed.csv'))
# Out:
# 15140
# 9307
# 14555

# %%
print(diff_preds('../output/inc_139.csv', '../output/subm_majorty.csv'))
print(diff_preds('../output/incres_140.csv', '../output/subm_majorty.csv'))
print(diff_preds('../output/inc_139.csv', '../output/incres_140.csv'))
# Out:
# 17688
# 9458
# 17625

# %% [markdown]
# ## diff for 5 models

# %%
files = ['../output/preds/resnet50_fixed.csv', '../output/preds/resnet50_224.csv', '../output/preds/inception.csv',
        '../output/preds/xception.csv', '../output/preds/vgg16_256_128.csv']

preds = []
for f in files:
    preds.append(pd.read_csv(f, header=None).values)
preds = np.array(preds)
print(preds.shape)

mean_preds_old = np.mean(preds, axis=0)
mean_labels_old = np.argmax(mean_preds, axis=1)

p_best = pd.read_csv('../output/subm_majorty.csv').label.values
p_best = np.array([NAME2ID[n] for n in p_best])
print(p_best.shape)
sum(mean_labels_old != p_best)
# Out:
# (5, 158538, 12)
# (158538,)
# 7836

# %%
dirs = ['r50_199', 'r50_244', 'xcep', 'inc_139', 'v16']

preds = []
for d in dirs:
    files = ['../output/preds/{}/fold_{}/test.csv'.format(d, i) for i in range(4)]
    cur_preds = []
    for f in files:
        print(f)
        cur_preds.append(pd.read_csv(f, index_col='fname').values)
    cur_preds = np.mean(cur_preds, axis=0)
    preds.append(cur_preds)

mean_preds = np.mean(preds, axis=0)
mean_labels = np.argmax(mean_preds, axis=1)

p_best = pd.read_csv('../output/subm_majorty.csv').label.values
p_best = [NAME2ID[n] for n in p_best]
sum(mean_labels != p_best)
# Out:
# ../output/preds/r50_199/fold_0/test.csv
# ../output/preds/r50_199/fold_1/test.csv
# ../output/preds/r50_199/fold_2/test.csv
# ../output/preds/r50_199/fold_3/test.csv
# ../output/preds/r50_244/fold_0/test.csv
# ../output/preds/r50_244/fold_1/test.csv
# ../output/preds/r50_244/fold_2/test.csv
# ../output/preds/r50_244/fold_3/test.csv
# ../output/preds/inc_139/fold_0/test.csv
# ../output/preds/inc_139/fold_1/test.csv
# ../output/preds/inc_139/fold_2/test.csv
# ../output/preds/inc_139/fold_3/test.csv
# ../output/preds/v16/fold_0/test.csv
# ../output/preds/v16/fold_1/test.csv
# ../output/preds/v16/fold_2/test.csv
# ../output/preds/v16/fold_3/test.csv
# 14882

# %%
sum(mean_labels_old != mean_labels)
# Out:
# 13555
